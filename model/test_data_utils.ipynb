# %%
import os
from general_utils import get_logger
from data_utils import get_trimmed_glove_vectors,  load_vocab, \
        get_processing_word

# %%
class Config():
    def __init__(self, load=True):
        """Initialize hyperparameters and load vocabs

        Args:
            load_embeddings: (bool) if True, load embeddings into
                np array, else None

        """
        # directory for training outputs
        if not os.path.exists(self.dir_output):
            os.makedirs(self.dir_output)

        # create instance of logger
        self.logger = get_logger(self.path_log)

        # load if requested (default)
        if load:
            self.load()
            
    def load(self):
        """Loads vocabulary, processing functions and embeddings

        Supposes that build_data.py has been run successfully and that
        the corresponding files have been created (vocab and trimmed GloVe
        vectors)

        """
        # 1. vocabulary
        self.vocab_words = load_vocab(self.filename_words)
        #self.vocab_tags  = load_vocab(self.filename_tags)
        #self.vocab_chars = load_vocab(self.filename_chars)

        self.nwords     = len(self.vocab_words)
        #self.nchars     = len(self.vocab_chars)
        #self.ntags      = len(self.vocab_tags)

        # 2. get processing functions that map str -> id
        #self.processing_word = get_processing_word(self.vocab_words,
        #        self.vocab_chars, lowercase=True, chars=self.use_chars)
        #self.processing_tag  = get_processing_word(self.vocab_tags,
        #        lowercase=False, allow_unk=False)

        # 3. get pre-trained embeddings
        self.embeddings = (get_trimmed_glove_vectors(self.filename_trimmed)
                if self.use_pretrained else None)
        
        
    dir_output = "results/large_lstm_test/"
    dir_model  = dir_output + "model.weights/"
    path_log   = dir_output + "log.txt"
        
    filename_words = "../../data/vocab.txt"
    
    filename_trimmed = "../../data/embedding_vectors.npy.npz"
    
    use_pretrained = True

# %% [markdown]
# ## Test

# %%
config = Config(load=True)

# %%
config.nwords
# Out:
# 1863820

# %%
config.vocab_words
# Out:
# {'': 8,
#  'дёда': 1340893,
#  'дитмансдорф': 51726,
#  'рандеву»': 105292,
#  'импредикативный': 1106054,
#  'καθηγητής': 1674480,
#  'земля…': 1036726,
#  'сосканировать': 533094,
#  'норбекова': 216937,
#  'отомо': 1797091,
#  'келлеру': 826991,
#  'кувандык': 1230511,
#  'bangombe': 76203,
#  'таллирдиевой': 173509,
#  'kamon': 463229,
#  'diskless': 1444169,
#  'xcix': 1048366,
#  'пренебрегающий': 378547,
#  'малороссиян»': 1540109,
#  'фастак': 1452245,
#  'fhm': 1365623,
#  'моле́': 1674758,
#  'тварью': 1054235,
#  'creativity»': 721495,
#  'нигматзянов': 806706,
#  'attribution': 485320,
#  'кальеро': 571121,
#  'folks»': 1636578,
#  'арлекино': 1717978,
#  'freezer': 130432,
#  'invicta': 442940,
#  'бенник': 1788054,
#  'трутнями': 1852498,
#  'фижака': 625211,
#  'алваладе': 707501,
#  'шерстоткацкой': 1290759,
#  'aoû': 532803,
#  'причетниками': 1226255,
#  'pyatyhatka': 1476867,
#  'çамрǎк': 1574610,
#  'anka': 323125,
#  'бачинскайте': 172164,
#  'синхараджа': 114839,
#  'tudjman': 405184,
#  'мбаби': 1375010,
#  'юсеньги': 944612,
#  'титулярника': 925480,
#  'штаммер': 620731,
#  'брюгге': 381132,
#  'веймарской': 307607,
#  'какового': 700063,
#  'кинообозреватель': 1542842,
#  'внутрицерковными': 1862625,
#  'katalin': 171294,
#  'концертником': 608814,
#  'позднеготическом': 23568,
#  'ориентализма»': 319077,
#  'sénat': 662434,
#  'одноступенного': 1667939,
#  'исключающие': 130554,
#  'тосики': 178954,
#  'диэдральной': 1551954,
#  'стифелия': 588966,
#  'аладин': 621267,
#  'rosiers': 837190,
#  'петтерссона': 1687847,
#  'колымы»': 1356208,
#  'онковеба': 1864321,
#  'хоуци': 926005,
#  'сухён': 1560427,
#  'дорожаевский': 698092,
#  'эркрата': 304413,
#  'бруклендсе': 785602,
#  'тольяттинцы': 271281,
#  'grigor': 207983,
#  'рендерится': 863991,
#  'атомистического': 501443,
#  'отличающего': 371833,
#  'стоунера': 71943,
#  'строим': 1386140,
#  'очі»': 254012,
#  'стелющейся': 105415,
#  'птолемея\xa0vi': 1720106,
#  'оливами»': 1719349,
#  'пёструю': 163398,
#  'imagestack': 718058,
#  'допилит': 1604707,
#  'прикрыв': 429039,
#  'деметриус»': 492683,
#  'химичев\xa0—': 355843,
#  'коррейра': 1333723,
#  'гвоздненская': 743802,
#  'клиринговые': 187452,
#  'басо': 21489,
#  'мартемон': 581512,
#  'рапида': 1376358,
#  'звукоснимателе': 199384,
#  'стерилизация\xa0—': 1479069,
#  'macarophaeus': 802228,
#  'спящих': 1189493,
#  'ctenochasmatinae': 87561,
#  'ник\xa0—': 1072645,
#  't_^': 1496747,
#  'bruennichi': 1083234,
#  'вейден': 1198199,
#  'slowár': 1805698,
#  'гражау': 449711,
#  'высокоимпедансное': 1837483,
#  'midnightblue': 62694,
#  'коридоне': 98471,
#  'lugares': 891739,
#  'эрогенной': 1799715,
#  'kroschel': 1131571,
#  'бронезащиты': 1530143,
#  'bedfellows': 1376757,
#  'гордыни»': 1721173,
#  'санаторными': 1234656,
#  'районглазовский': 1681287,
#  'протопападакиса»': 241824,
#  'безъядерным': 773493,
#  'осеменению': 186214,
#  'проиллюстрированные': 584469,
#  'таргариены': 1350684,
#  'saltatorium': 461511,
#  'iюля': 1306065,
#  'фетальную': 370666,
#  'скалкин': 267531,
#  'naquet': 960325,
#  'испаноязычных': 349982,
#  'средневосточные': 125071,
#  'файвела': 648281,
#  'комиссаржевского\xa0—': 1735598,
#  'энергетики,': 236377,
#  'администрати́вный': 1321745,
#  'завязке': 1010459,
#  'subpages': 43142,
#  'nachkriegszeit': 1428096,
#  'зольное': 680304,
#  'карски': 521589,
#  'киня': 1248567,
#  'схавает': 1360278,
#  'бюджету': 95196,
#  'achumawi': 136278,
#  'tweedie': 23979,
#  'willst': 167228,
#  'экзотическая': 128944,
#  'brassavola': 747054,
#  'друзь\xa0—': 1616101,
#  'народника': 463646,
#  'warhorse': 1579723,
#  'пантодонты': 143080,
#  'кальсин': 584714,
#  'срача': 1843233,
#  'ивоби': 806813,
#  'воздушной': 225161,
#  'рабы»': 817376,
#  'пилер': 557943,
#  'ополовниковой': 1128684,
#  'u}': 1763491,
#  'рудзинские': 1339813,
#  'брасовская': 812425,
#  'виндгассен': 217879,
#  'бычке': 1153030,
#  'hooft': 1399503,
#  'зуру': 1778419,
#  'дуклянина': 314874,
#  'opportunity»': 1216998,
#  'дипилидиоз': 1715368,
#  'витторио\xa0—': 249832,
#  'битбоксер': 27173,
#  'подсоединив': 1653761,
#  'загрузок': 672258,
#  'sinistrals': 1282193,
#  'хоминьский': 864230,
#  'топот': 574739,
#  'оромокто': 1393807,
#  'lepsius': 82575,
#  'фантлаб': 607929,
#  'мусика': 241083,
#  'торгильсу': 805255,
#  'дувановская': 1059432,
#  'shue': 1379995,
#  'карлштадт': 1334402,
#  'raccoonus»': 207919,
#  'лишавшие': 641164,
#  'defeis/starr': 1130520,
#  'вышесказаного': 715386,
#  'пустующие': 919655,
#  'барлов': 127630,
#  'минералокортикоиды': 693834,
#  'ford%': 967519,
#  'abcdef': 1194945,
#  'тахиаташ': 576186,
#  'оксалоацетата': 952562,
#  'обвязочные': 1597621,
#  'хейска': 1839172,
#  'willingen': 1593252,
#  'typesafe': 1266654,
#  'анисии': 440010,
#  'балланже': 366250,
#  'ларинскую': 1221432,
#  'чх': 512174,
#  'нуклеазы': 1306444,
#  'возводиться': 102144,
#  'цвета,\xa0—': 1171646,
#  'delagrave': 802461,
#  'болшева': 457383,
#  'muslimstr': 1360942,
#  'йовович': 1755425,
#  'островно»': 4160,
#  'скуинь': 18395,
#  'майкаин': 676655,
#  'дайр': 1793061,
#  'видящая': 1185927,
#  'шифроалгоритм': 1340230,
#  'вымотан': 1739909,
#  'hohenwart': 942684,
#  'григориади': 98196,
#  'одномандатного': 412683,
#  'грабовенко': 1829268,
#  'разбиении': 1442815,
#  'трабзонспоре»': 902377,
#  'керма»': 1173442,
#  'зимовец': 1545817,
#  'руководство\xa0—': 1056116,
#  'альмандар': 806934,
#  'оборвется': 536113,
#  'перетта': 610267,
#  'oest': 1487162,
#  'аю́н': 759562,
#  'lukasik': 491890,
#  'системс': 355555,
#  'киммел': 1303916,
#  'communitates': 325197,
#  'баронъ': 1698510,
#  'сурав': 1686313,
#  'быньговского': 365626,
#  'шахтные': 1181304,
#  'убайя': 471419,
#  'твенте»': 1633384,
#  'помогают»': 1842109,
#  'шундук': 949245,
#  'непоследовательном': 1003311,
#  'санур': 1737033,
#  'acholi': 1651588,
#  'wbr_': 1776105,
#  'wayland\xa0—': 1482105,
#  'истинка': 1252170,
#  'ильей': 1142094,
#  'обращённых': 1565880,
#  'mejer': 1395387,
#  'локомотивному': 125575,
#  'айявари': 1302471,
#  'столлмэн': 777350,
#  'янокопулос': 1825471,
#  'длинноязычные': 1164916,
#  'уоткинсу': 1276797,
#  'мегапроектам': 562397,
#  'амебоидных': 1626939,
#  'сё': 895711,
#  'пилонный': 709208,
#  'l\\left': 1146314,
#  'столыпиных': 1293751,
#  'здравомыслии': 1851652,
#  'макеевка\xa0—': 1388629,
#  'fontdata': 1431318,
#  'columna': 1498308,
#  'краснеют': 500877,
#  'помаде': 153828,
#  'kommentierte': 1853160,
#  'пригорода\xa0—': 1465035,
#  'scutellum': 1261239,
#  'оккк': 302724,
#  'чжиюаня': 355209,
#  'интонаций': 386079,
#  'хазанское': 1650372,
#  'бомбардировочном': 422576,
#  'джамаата»': 1485649,
#  'искрящимися': 1626959,
#  'публицистики»': 1298059,
#  'org/action/dosearch': 1656365,
#  'зандманн': 2396,
#  'объявившегося': 67352,
#  'геральдиков': 1682396,
#  'драговоляц': 1633424,
#  'rpjahxffcwkhcyrdgaq': 199704,
#  'кнб': 634608,
#  'ulises': 1215474,
#  'оптимистичного': 1690949,
#  'кессонным': 1167648,
#  'сохранения': 1418997,
#  'указательных': 1615799,
#  'камсинг': 1007502,
#  'райкомвода»': 485416,
#  'bgn/pcgn': 73206,
#  'спонсированием': 1288590,
#  'зажигающим': 579669,
#  'лансере́': 25891,
#  'триизодонтиды': 582201,
#  'эмирийская': 1695584,
#  'раннеземледельческие': 1493247,
#  'спаак\xa0—': 870128,
#  'деноминациях': 249138,
#  'bendzko': 1457361,
#  'сдающих': 801143,
#  'typhon': 144262,
#  'кобизева': 1193863,
#  'джандер': 336430,
#  'динамо»\xa0—': 1173853,
#  'point_id': 348136,
#  'mandolin': 1466161,
#  'аскетика': 590965,
#  'отоки': 505546,
#  'межколёсных': 1457033,
#  'taurus': 1633794,
#  'łowicz': 633477,
#  'граунд»': 1859701,
#  'stuleciu': 1056513,
#  'протеомного': 1343054,
#  'селайя»': 605091,
#  'ирмес': 1823263,
#  'направленность\xa0—': 656083,
#  'стеклонить': 87696,
#  'явившиеся': 1024526,
#  'dimanižnik✉': 1720506,
#  'подинституты': 1608928,
#  'ротшильда': 1176284,
#  'melikşah': 1163144,
#  'фонсаграда': 109992,
#  'нейбург': 528370,
#  'горбаневской': 79840,
#  'слэма': 793911,
#  'украинского/русинского': 446597,
#  'визгливым': 320171,
#  'названном': 216234,
#  'periegopidae': 505518,
#  '/мо': 1075293,
#  'ростопчинской': 95754,
#  'развариваются': 59765,
#  'кахновка': 1211449,
#  'лишишься': 790639,
#  'азбруке': 820888,
#  'подступах': 522765,
#  'маслобойной': 151496,
#  'эфиоп»': 703969,
#  'энспач': 1538022,
#  'шуанляо': 695107,
#  'поселениебезверховское': 548415,
#  'нейротизм': 711908,
#  'решетчатыми': 506701,
#  'меняет»': 1860051,
#  'врунгель': 238693,
#  'хибин»': 300047,
#  'мичко': 1029634,
#  'виновника»': 777177,
#  'südwesten': 1290303,
#  'римская\xa0—': 360095,
#  'копжасар': 1596213,
#  'глашу': 1107102,
#  'фелдманис': 609750,
#  'гцкз': 416074,
#  'меттманн': 801955,
#  'макариевские': 192518,
#  'преломились': 652046,
#  'камышня': 291611,
#  'демонически': 771512,
#  'пайпс,': 1344210,
#  'skee': 236506,
#  'самоотдача': 1685254,
#  'freshtel': 163315,
#  'монтируемым': 503321,
#  'пенула': 649066,
#  'сержпинский': 838863,
#  'раскаленного': 60248,
#  'gfx': 1792892,
#  'darien': 33719,
#  'герициевые': 356435,
#  'ivanovskaya': 82564,
#  'привязные': 1073479,
#  'каша\xa0—': 338741,
#  'обделен': 1391027,
#  'курортник': 539614,
#  'универсиаде': 643494,
#  'blaptini': 356494,
#  '#руденко': 498292,
#  'elmgreen': 1256655,
#  'трогает»': 382772,
#  'карнация': 1640601,
#  'montagu': 1129005,
#  'предрассудков': 406726,
#  'скинуться': 1250396,
#  'норбургской': 1729371,
#  'ибн»': 736097,
#  'энгельманом': 276159,
#  'кашмирской': 790757,
#  'коррелятивный': 1856710,
#  'дозаривания': 1742307,
#  'сарымсак': 1268424,
#  'а́ндрис': 29929,
#  'rhizocarpon': 1426148,
#  'арраго': 206022,
#  'организаций\xa0—': 346027,
#  'шиндхельм': 1518086,
#  'сарача': 581689,
#  'проговорила': 1064105,
#  'цебельду': 1773021,
#  'org/wikipedia/en/': 107082,
#  'ясудзо': 884430,
#  'sulmona': 1684179,
#  '…впрочем': 1240426,
#  'гандболе': 807388,
#  'вейентам': 910198,
#  'психастеникам': 627478,
#  'тешенит': 531133,
#  'канализационное': 1198889,
#  'тырса': 584666,
#  'днепров\xa0—': 14515,
#  'пророщенного': 1108276,
#  'литургическими': 215838,
#  'доджерсом': 257956,
#  'посоветую': 1802551,
#  'фортунис': 835785,
#  'мягкотелыми': 331671,
#  'метельский': 729848,
#  'nkz': 1836287,
#  'размножалась': 1528622,
#  'хэвенли': 296599,
#  'вспахали': 13747,
#  'спг\xa0—': 289243,
#  'марцваладзе': 1683563,
#  'чирибом': 1586132,
#  '„суд': 868252,
#  'брестчане': 1657699,
#  'паруро': 171127,
#  'фросо': 1264965,
#  'макрины': 1542675,
#  'объективацию': 143210,
#  'капотнинским': 1782440,
#  'тиосто': 396981,
#  'снитко': 1541386,
#  'палагея': 1595990,
#  'großstadt': 1493300,
#  'schnella': 1521208,
#  'тараном': 156834,
#  'chemokine': 1562575,
#  'янидор': 1577315,
#  'несодержательные': 1681875,
#  'винии': 1619937,
#  'колесничим': 833538,
#  'cirkut': 1198702,
#  'держащейся': 1449117,
#  'усиливали': 1313564,
#  'летоянни': 1185665,
#  'мсч': 946942,
#  'пейрер': 18127,
#  'подцензурной': 343490,
#  'khimkinsky': 1178326,
#  'ольвертер': 1347105,
#  'коринфскую': 1449298,
#  'фотоаппарат': 47817,
#  'поликовская': 618297,
#  'омоложение': 1847073,
#  'неразрушимости': 833661,
#  'бронемодули': 88608,
#  'маццакурати\xa0—': 1162786,
#  'дюжой': 538326,
#  'iddqd': 1538246,
#  'арапом': 349417,
#  'подфорум': 706078,
#  'туранги': 249629,
#  'тундутову': 363685,
#  'проломили': 1478272,
#  'виноделов»': 632975,
#  'пневмозакладочные': 1456054,
#  'челкасинского': 1709487,
#  'сабельных': 1421073,
#  'имперско': 138718,
#  'ганапольский': 719993,
#  'шелбивилльские': 777913,
#  'ниисф': 1671438,
#  'умбертом': 1064880,
#  'ретропоездок': 214025,
#  'круизинга': 1534042,
#  '‑литровый': 516335,
#  'лэнгфорду': 558802,
#  'сливается»': 1660402,
#  'эрнестинов': 861451,
#  'правдоподобных': 617093,
#  'пекинском': 1805237,
#  'basf»': 1438785,
#  'хамагаттинский': 354142,
#  'адевале': 560846,
#  'адмета': 388674,
#  'токов»': 613340,
#  'тухфат': 1051749,
#  'gause': 317559,
#  'шмыгов': 307032,
#  'необычайная': 619014,
#  'вавринке': 870535,
#  'альвы': 238724,
#  'тарандтской': 454717,
#  'стереонаушники': 1224499,
#  'vulnerabilities': 75097,
#  'крокера': 276141,
#  'выяснения»': 1813925,
#  'шмата': 1423052,
#  'учинская': 1474942,
#  'цийон': 554436,
#  'лондонде́рри': 245108,
#  'конференционном': 624802,
#  'бургуэн»': 1786692,
#  'подфорумы': 255041,
#  'tiesto': 707981,
#  'падка': 1140810,
#  'mindful': 175030,
#  'хлеб\xa0—': 963190,
#  'бэкронимом': 1518706,
#  'признававшие': 1772419,
#  'playerid': 785437,
#  'лавовыми': 1690264,
#  'апогея\xa0—': 735775,
#  'души,': 1818915,
#  '/topic/': 233487,
#  'bezirkshauptmann': 306142,
#  'развевающейся': 1439635,
#  'дурачком': 1189023,
#  'ремесленников»': 1654850,
#  'ассизского»': 945827,
#  'парольной': 1609817,
#  'карповичский': 1201225,
#  'мундиров': 892205,
#  'эпителиоцитов': 1477730,
#  'дхармапала': 1054023,
#  'физкультурной': 148787,
#  'биовар': 311131,
#  'союзническое': 948601,
#  'цепную': 21956,
#  'συμμετοχή': 202178,
#  'silently': 311639,
#  'сибиряки': 676998,
#  'giuffria': 682597,
#  'округростовский': 1160543,
#  'жидовка': 597076,
#  'оцифрованную': 842402,
#  'umrisse': 295431,
#  '§§': 1442227,
#  'баянтал': 822062,
#  'tplusgroup': 181573,
#  'piratas': 1803132,
#  'палочку': 1568544,
#  'ценам\xa0—': 963399,
#  'валентим': 732132,
#  'свеби': 349800,
#  'лютный': 386473,
#  'гипноз\xa0—': 871129,
#  'satzung': 202044,
#  'левенвольд': 1849114,
#  'мамонов»': 1798305,
#  'сёдлами': 1773810,
#  'отрадная': 1176706,
#  'kirchhain': 1092508,
#  'каракумское': 1571677,
#  'веникеев': 782903,
#  'энгуразово': 368387,
#  'подзаконные': 956242,
#  'шеберта': 1719247,
#  'перечково': 269542,
#  'mы': 812767,
#  'курагинском': 227534,
#  'делений\xa0—': 1628874,
#  'атаманика': 1825039,
#  'альфа»\xa0—': 863035,
#  'batna': 1692056,
#  'мухамедова': 374463,
#  'desmosomatidae': 473759,
#  'veni': 430648,
#  'скорбят': 1548472,
#  'puntland': 1573221,
#  'транспирация': 1291020,
#  'титурель»': 500764,
#  'мюльрозе': 411910,
#  'dancefloor': 642079,
#  'béth': 571593,
#  'снайперша': 458304,
#  'келифский': 903503,
#  'матен»': 1445851,
#  'continens': 246676,
#  '//engine': 16329,
#  'баллала': 1668183,
#  'ancistrophora': 1372788,
#  'великомлыновецкий': 1106835,
#  'беспоместный': 78293,
#  'локальная»': 221077,
#  'березиниан': 1473855,
#  'левичевского': 168567,
#  'homeless': 1452998,
#  'pomhaj': 1234537,
#  'летюшова': 1042977,
#  'ostengruppe»': 1580853,
#  'гютербок': 1784087,
#  'неплатежей': 1828993,
#  'отвлекаясь': 179282,
#  'plagiolophus': 1612274,
#  'камыслыбас': 547297,
#  'o\\': 569720,
#  'хуторянам': 255416,
#  'эспаса»': 1088082,
#  'батумский': 1645291,
#  'чугуевки': 953400,
#  'rails': 599134,
#  'типчака': 983386,
#  'orest': 1183652,
#  'помазал': 1725475,
#  'фазанерия': 64220,
#  'сопят': 1186551,
#  'данько': 657265,
#  'farhad': 1586869,
#  'лебрён': 271842,
#  'этнографическим': 1592944,
#  'нострадамуса': 1221592,
#  'лонгплея': 748173,
#  'сексуализация': 672593,
#  'гайана}}': 953085,
#  'показавшейся': 1103227,
#  'anatomy': 513476,
#  'паэта': 229272,
#  'кавкорпус': 163716,
#  'breitenau': 49007,
#  'printre': 366099,
#  'финдлиата': 771931,
#  'кэннон»': 1696432,
#  'омофония': 1663132,
#  'онк': 527543,
#  'гоголю\xa0—': 377006,
#  'вкладчикам': 1837592,
#  'нджогу': 1551342,
#  'atrophaneura': 1492053,
#  'дым…': 1285006,
#  'щегловитовы': 1669938,
#  'шахоб': 1523324,
#  'насыпь': 1722143,
#  'поселениечугуевское': 576760,
#  'вернета': 223803,
#  'arccos': 262884,
#  'интерим': 1469129,
#  'toboso': 1361111,
#  'характером»': 1171498,
#  'тарасюком': 1803096,
#  'кирцикский': 1558099,
#  'репузи': 319800,
#  'харихара': 543698,
#  'кицунэ»': 925324,
#  'джиганте': 217080,
#  'верховцево\xa0—': 472699,
#  'телесценарий': 1544788,
#  'галагоц': 702298,
#  'либена»': 1705514,
#  'энджелс': 236602,
#  'эворы': 1745856,
#  'опасности»': 1777209,
#  'komischen': 1203658,
#  'ухудшат': 1405878,
#  'elettrico': 250659,
#  'sulcicollis': 55371,
#  'сиюминутный': 964927,
#  'цзиньдэ»': 1403018,
#  'поселениекриушанское': 1493301,
#  'найденова': 143387,
#  'наваджеро': 1338113,
#  'садриддину': 1076377,
#  'трафарет': 995575,
#  'discovers': 636313,
#  'делянка»': 1220674,
#  'uhren': 1710364,
#  'remedios': 827547,
#  'советах»': 590526,
#  'ghiutun': 1755017,
#  'гариб': 777311,
#  'patty': 1145599,
#  'arcana\xa0—': 1494243,
#  'подогретую': 1690247,
#  'склянок': 1448159,
#  'tysiąclecia': 252874,
#  'леонова': 1708888,
#  'отражавшем': 1163105,
#  'киноляпов»': 1454233,
#  'потягивать': 929373,
#  'эссьен': 1815554,
#  'hotrod»': 1547841,
#  'обручальная': 1821387,
#  'газикумухском': 724082,
#  'пугавшего': 169602,
#  'ломски': 1207797,
#  'маркоч': 69263,
#  'мажар': 751519,
#  'роллса': 546584,
#  'коленкура': 1267955,
#  'знакомца': 896071,
#  'гарз': 676406,
#  'huset': 207501,
#  'завадовского': 1521523,
#  'хорезмийскую': 727068,
#  'фотометрия': 1556571,
#  'бранник': 48614,
#  'vj': 942144,
#  'обучает': 8375,
#  'окунёвое': 705620,
#  'glenys': 194863,
#  'баталией': 1764136,
#  'скевра': 1679686,
#  'рептилии': 201437,
#  'придраться': 534568,
#  'кифара»': 1076336,
#  'беспристрастию': 1695869,
#  'смоктуновском': 277683,
#  'барьюдина': 869876,
#  'пати»': 40422,
#  'división': 453971,
#  'веерообразное': 1527015,
#  'hochstetten': 439411,
#  'виднеющимися': 435034,
#  'патаниоти': 563821,
#  'su/publ/': 1486835,
#  'выполняю': 408547,
#  'фисинин': 1419900,
#  'упорному': 763932,
#  'подкорпуса': 1451034,
#  'зарамагскому': 1305850,
#  'санься': 875434,
#  'кзкт': 1210408,
#  'vendetta»': 1488458,
#  'bottomless': 643726,
#  'яньдун': 1150305,
#  'иссигри': 144384,
#  'тогутил': 1030404,
#  'constructing': 1576965,
#  'чугинадак': 382722,
#  'кирлеутского': 23955,
#  'ромарио»': 1355156,
#  'pgt': 961309,
#  'высоколегированной': 846281,
#  'gardee': 29971,
#  'эстатиуса\xa0—': 1601375,
#  'манджула': 67939,
#  'рахзада': 1735714,
#  'ухдуд': 305585,
#  'ууксу': 1714374,
#  'физикохимика': 1494352,
#  'абердинскому': 590164,
#  'шмелькова': 256948,
#  'ремесленника»': 1092316,
#  'стаити': 1155165,
#  'ближневосточного': 80935,
#  'польми': 707891,
#  'осория': 359323,
#  'зусмановский': 9376,
#  'брогольмер': 849356,
#  'гаалом': 648778,
#  'шомона': 340609,
#  'wulfsonом': 355879,
#  'эспаньолом»': 85078,
#  'соколовское': 84448,
#  'выдвинутого': 1023155,
#  'мосты': 402256,
#  'схинделер': 1096884,
#  'засовов': 1342236,
#  'выхватив': 27351,
#  'документационное': 961404,
#  'вехби': 1446803,
#  'серпантином': 1208115,
#  'сомервилль': 1739373,
#  'полухиным': 1204015,
#  'уйтелки': 701910,
#  'кириат': 1046051,
#  'jumătate': 829133,
#  'юстициарий': 346366,
#  'мошава': 633168,
#  'бежарии': 740909,
#  'ордумелик': 865256,
#  'леонас': 223559,
#  'с\xa0просьбой': 540355,
#  'бонен': 1652924,
#  'ольгополе': 1715951,
#  'граждан,': 433179,
#  'шёнг': 881080,
#  'quita': 638347,
#  'компилирующего': 1807955,
#  'смокингов': 37583,
#  'седаково': 1530454,
#  'комнатную': 759209,
#  'skulpturen': 1851440,
#  'маммографию': 572598,
#  '\\sum^r_': 493636,
#  'мечетской': 197166,
#  'опен»': 1723656,
#  'чорикова': 1681670,
#  'ливади': 819036,
#  'генотип»': 729918,
#  'theravāda': 1807398,
#  'кампамба': 338597,
#  'энвонву': 1679163,
#  'незвалом': 1113956,
#  'пюльве': 800860,
#  'неарабским': 1464347,
#  'мередита': 1727508,
#  'бескиды»': 1816193,
#  'рафенштайн': 1491495,
#  'колоале»': 862613,
#  'обветшавшая': 1845084,
#  'медведницы': 1223127,
#  'джексоном': 1257294,
#  'исуп': 120975,
#  'gunga': 550577,
#  'мингажетдинов': 839597,
#  'yunnanense': 1030667,
#  'vlašim': 1479829,
#  'пратчетта': 745848,
#  'незатухающие': 1744406,
#  'округкаракыстакский': 417848,
#  'никопольский»': 837086,
#  'нелепую': 301253,
#  'компанейским': 461788,
#  'ундервуд\xa0—': 1648877,
#  'ячменка': 321463,
#  'слепа': 237551,
#  'кришна\xa0—': 1794982,
#  'ngenix': 1670271,
#  'сакин': 904744,
#  'искусство»,': 1089353,
#  'teikyo': 905588,
#  'гофмейстеров': 732482,
#  'casspir': 1650032,
#  'каммершпиле»': 398915,
#  'кузовкин': 957806,
#  'составившие': 1791672,
#  'обернется': 1506658,
#  'tulle': 88050,
#  'бытувского': 1411085,
#  'харет': 1082596,
#  'f\\phi': 526395,
#  'stanga': 864619,
#  'вдовствовали': 260922,
#  'жиделев': 383476,
#  'bwalya': 1576762,
#  'буиар': 1335667,
#  'дездемона': 19257,
#  'повлекшие': 79558,
#  'лаплейс': 1005099,
#  'хараппским': 539896,
#  'нейроваскулярный': 28870,
#  'сяобаочжуан»': 42548,
#  'выцветшим': 945695,
#  'венгерский\xa0—': 479512,
#  'руднёв': 487690,
#  'агнезе': 1520944,
#  'тимашёвск': 352586,
#  'соловой': 879577,
#  'govoryat': 1278275,
#  'рюдзё': 434920,
#  'водится': 1246316,
#  'сяберо': 1685049,
#  'чанковская': 1679869,
#  'галогенидных': 398410,
#  'ниснас': 308274,
#  'seeleyi': 300014,
#  'посполитаяроссийская': 46835,
#  'landaulet': 1558708,
#  'эссенциальные': 1644552,
#  'автострад': 926464,
#  'адъютантом': 557630,
#  'archéologique': 272024,
#  'пакхоуку': 1803638,
#  'синдона': 992909,
#  'лепхалале': 1549426,
#  'перемену': 987419,
#  'talaud': 1463152,
#  'исходный': 84202,
#  'валадас': 290312,
#  'макклюр\xa0—': 1378006,
#  'пазрецких': 1683151,
#  'адзу': 466624,
#  'ливенов': 548510,
#  'амировка': 744546,
#  'медэти': 1627818,
#  'персиваль': 1087777,
#  'яте': 525691,
#  'англивьель': 990651,
#  'dobříš': 585896,
#  'хитрин': 1421593,
#  'огородники': 1224032,
#  'respubliki': 1843841,
#  'негрис': 530735,
#  'typewriting': 441564,
#  'вулканического': 107448,
#  'competizione': 354586,
#  'глашан': 1765886,
#  'альбинони\xa0—': 440598,
#  'сегином': 1506004,
#  'гин\xa0—': 528371,
#  'постмодерном': 1012827,
#  'смосарская\xa0—': 489620,
#  'отлучении': 1468270,
#  'полiтбюро': 1585372,
#  'определяющие': 849103,
#  '//pitchfork': 1257710,
#  'caloris': 695619,
#  'обсуждение_проекта': 123694,
#  'кошмарных': 1218885,
#  'сердечник\xa0—': 25821,
#  'ханмин': 712346,
#  'ришери': 1215531,
#  'centras»': 621828,
#  'ru/modules': 1565968,
#  'углян': 781869,
#  'колчин\xa0—': 682169,
#  'экий': 1206770,
#  'jiljí': 1348401,
#  'саркастическим': 1374508,
#  'степерь': 550153,
#  'со\xadвета': 1433282,
#  'финляндская': 685278,
#  'галита': 1618409,
#  'недзельского': 1445995,
#  'süßwasserarten': 1856141,
#  'институции»': 1210250,
#  'mistr': 515198,
#  'посполитого': 85527,
#  'всплывающим': 524769,
#  'геологоразведчиков': 1779261,
#  'машэрава': 43331,
#  'перекрытый': 1634697,
#  'алманах»': 1689471,
#  'костена': 384434,
#  'струкачёв': 1770476,
#  'нордами': 1514021,
#  'platformer': 1721043,
#  'лоцава': 1612600,
#  'досылка': 1698177,
#  'питино': 691470,
#  'токино': 1762387,
#  'громагин': 1325558,
#  'расстраивая': 586893,
#  'звездчатки': 244892,
#  'биржу': 939673,
#  'gussmann': 1812659,
#  'видеокурсы': 225445,
#  'допусти́м': 1102900,
#  'скарлатины': 456729,
#  'дивизионная': 165107,
#  'ироничному': 360974,
#  'гранильо': 7814,
#  'экуэле': 259275,
#  'сnn': 66062,
#  'священнослужению': 1402067,
#  'мезоамериканская': 1210489,
#  'радуй': 36913,
#  'тоир': 73241,
#  'вакис': 1043037,
#  'guyader': 1592990,
#  'рексо': 1546235,
#  'хирагане': 153113,
#  'танцовщице': 701239,
#  'десятиліття': 578453,
#  'леонин': 192532,
#  'distributions': 1752794,
#  'натрона\xa0—': 459978,
#  'periods': 1469061,
#  'леофвина': 797615,
#  'техническом»': 1755281,
#  'wyclef': 85579,
#  'corusca': 1355303,
#  'борис»': 1150805,
#  'cta': 1098276,
#  'саломон»': 1429788,
#  'горшколепов': 520490,
#  'стеклоделия': 1494423,
#  'неоведантизм': 767622,
#  'отмотка': 357848,
#  'йонеско': 1662518,
#  'дадададъ': 970299,
#  'волонтеру': 1746444,
#  'зернотрест»': 68400,
#  'провокационных': 393459,
#  'сглажены': 306846,
#  'новоишимского': 1783530,
#  'нектаром': 988150,
#  'ангулеса': 792948,
#  'клеваева': 1687251,
#  'севастополь»\xa0—': 1401299,
#  'estación': 272703,
#  'подстриженный': 1836190,
#  'мичоакан': 382362,
#  'график\xa0—': 1594552,
#  'мысливский': 1558147,
#  'ненашел': 1825421,
#  'кундола': 106797,
#  'гипертриглицеридемией': 238994,
#  'xv—xii\xa0вв': 600482,
#  'ашимбаев': 842732,
#  'алексинским': 1014830,
#  ...}
