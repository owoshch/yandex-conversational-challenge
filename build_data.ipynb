# %% [raw]
# from model.data_utils import CoNLLDataset, get_vocabs, UNK, NUM, \
#     get_glove_vocab, write_vocab, load_vocab, get_char_vocab, \
#     export_trimmed_glove_vectors, get_processing_word

# %%
import pandas as pd
import numpy as np
import requests
import tqdm
import pymorphy2
from model.config import Config
from model.data_utils import UNK, NUM, BEGIN, END, \
    get_glove_vocab, write_vocab, load_vocab, \
    export_trimmed_glove_vectors, get_processing_word, \
    get_vocab, get_unique_column_words, correct_sentence, \
    change_letter, unk_to_normal_form

# %%
config = Config(load=False)

# %%
train = pd.read_csv(config.path_to_train_dataframe, error_bad_lines=False, sep = '[  . ? , !]?\t', 
                   header=None)
# Out:
# /Users/kitashov/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
train.columns = config.train_column_names

# %%
train_vocab = get_vocab(train, config.train_vocab)
# Out:
# getting unique words from context_2
# getting unique words from context_1
# getting unique words from context_0
# getting unique words from reply

# %%
len(train_vocab)
# Out:
# 41059

# %%
public = pd.read_csv(config.path_to_test_dataframe, error_bad_lines=False, sep = '[  . ? , !]?\t', 
                   header=None)
# Out:
# /Users/kitashov/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
public.columns = config.test_column_names

# %%
test_vocab = get_vocab(public, config.test_vocab)
# Out:
# getting unique words from context_2
# getting unique words from context_1
# getting unique words from context_0
# getting unique words from reply

# %%
vocab_fasttext = get_glove_vocab(config.path_to_embedding_vectors)
# Out:
# Building vocab...
# - done. 1862491 tokens

# %% [raw]
# def unk_to_normal_form(dataset_vocab, vocab_fasttext, path_to_dict):
#     changes = dict()
#     morph = pymorphy2.MorphAnalyzer()
#     unfound_words = dataset_vocab - vocab_fasttext
#     for word in tqdm.tqdm(unfound_words):
#         new_word = correct_sentence(word)
#         if '€' in new_word:
#             new_word = change_letter(new_word, '€', 'я')
#
#         if '√' in new_word:
#             new_word = change_letter(new_word, '√', 'г')
#
#         if new_word == '<CENSORED>':
#             new_word = 'censored'
#
#         p = morph.parse(new_word)[0]
#         if p.normal_form in vocab_fasttext:
#             changes[word] = p.normal_form
#     np.save(path_to_dict, change)
#
#     return changes

# %%
train_unk_to_normal = unk_to_normal_form(train_vocab, vocab_fasttext, config.train_unk)
# Out:
# Loading dictionaries from /Users/kitashov/anaconda/envs/tensorflow/lib/python3.5/site-packages/pymorphy2_dicts/data
# format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
#   0%|          | 0/2017 [00:00<?, ?it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text= HTTP/1.1" 200 2
#   0%|          | 1/2017 [00:00<11:36,  2.90it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%B5%D1%80%D0%B5%D0%BA%D1%83%D1%81%D0%B8 HTTP/1.1" 200 2
#   0%|          | 2/2017 [00:00<11:37,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D1%82%D1%83%D1%81%D0%B8%D0%BC HTTP/1.1" 200 103
#   0%|          | 3/2017 [00:01<11:41,  2.87it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=105 HTTP/1.1" 200 2
#   0%|          | 4/2017 [00:01<11:43,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=zogo HTTP/1.1" 200 77
#   0%|          | 6/2017 [00:01<09:45,  3.43it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BD%D0%B5%D0%B7%D0%B0%D0%BF%D0%B5%D1%80%D1%82%D0%B0 HTTP/1.1" 200 172
#   0%|          | 7/2017 [00:02<10:03,  3.33it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D0%
  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%82%D0%BE%D1%80%D1%87%D0%B8%D1%82%D0%B5 HTTP/1.1" 200 2
#  99%|█████████▉| 1998/2017 [11:26<00:06,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D1%80%D0%BE%D0%B5%D0%B7%D0%B6%D0%B0%D0%B9%D1%82%D0%B5 HTTP/1.1" 200 2
#  99%|█████████▉| 1999/2017 [11:27<00:06,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B8%D1%81%D1%86%D0%B5%D0%BB%D1%8F%D1%8E%D1%81%D1%8C HTTP/1.1" 200 2
#  99%|█████████▉| 2000/2017 [11:27<00:05,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%BE%D0%B4%D0%B8%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  99%|█████████▉| 2001/2017 [11:27<00:05,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BE%D1%82%D1%81%D0%BE%D1%81%D1%83 HTTP/1.1" 200 2
#  99%|█████████▉| 2003/2017 [11:28<00:04,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%BC%D0%B5%D1%88%D0%B8%D0%B2%D0%B0%D0%B5%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  99%|█████████▉| 2004/2017 [11:28<00:04,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BD%D0%B0%D0%B4%D0%B5%D0%BD%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
#  99%|█████████▉| 2005/2017 [11:28<00:04,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D0%BA%D0%BE%D0%BD%D1%87%D0%B8%D1%88%D1%8C HTTP/1.1" 200 2
#  99%|█████████▉| 2006/2017 [11:29<00:03,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%80%D0%B0%D0%B7%D0%B1%D0%B5%D0%B3%D0%B0%D0%B5%D0%BC%D1%81%D1%8F HTTP/1.1" 200 2
# 100%|█████████▉| 2007/2017 [11:29<00:03,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%BB%D0%B0%D0%BC%D1%8B%D0%B2%D0%B0%D0%B5%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
# 100%|█████████▉| 2008/2017 [11:30<00:03,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BA%D0%B0%D0%BD%D1%82%D0%BC%D0%B8%D1%81 HTTP/1.1" 200 154
# 100%|█████████▉| 2009/2017 [11:30<00:02,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%B5%D1%80%D1%88%D0%B8%D1%82 HTTP/1.1" 200 2
# 100%|█████████▉| 2010/2017 [11:30<00:02,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B8%D0%B7%D0%B1%D0%B5%D0%B3%D0%B0%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
# 100%|█████████▉| 2011/2017 [11:31<00:02,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%82e%D0%B1%D1%8F HTTP/1.1" 200 106
# 100%|█████████▉| 2012/2017 [11:31<00:01,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B1%D0%BE%D0%B6%D0%B5%D1%87%D0%BA%D0%B8 HTTP/1.1" 200 103
# 100%|█████████▉| 2013/2017 [11:31<00:01,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B4%D0%BE%D1%81%D1%82%D0%B0%D0%B2%D0%BB%D1%8F%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
# 100%|█████████▉| 2014/2017 [11:32<00:01,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%84%D0%BB%D0%B5%D1%87%D0%B5%D1%80 HTTP/1.1" 200 141
# 100%|█████████▉| 2015/2017 [11:32<00:00,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%83%D0%BD%D0%B0%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D1%8E HTTP/1.1" 200 2
# 100%|█████████▉| 2016/2017 [11:32<00:00,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B1%D0%B5%D1%80%D0%B5%D0%B6%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
# 100%|██████████| 2017/2017 [11:33<00:00,  2.91it/s]

# %%
train_unk_to_normal
# Out:
# {'шэйд': 'шэд',
#  'перекуси': 'перекусить',
#  'прикусил': 'прикусить',
#  'оплати': 'оплатить',
#  'ржешь': 'ржать',
#  '√рег': 'грег',
#  'zogo': 'zoo',
#  'фетч': 'фет',
#  'заберем': 'забрать',
#  'дерьмового': 'дерьмовый',
#  'отследи': 'отследить',
#  'джэд': 'дед',
#  'ватит': 'хватит',
#  'трахайся': 'трахаться',
#  'привлекаешь': 'привлекать',
#  'закрывайся': 'закрываться',
#  'увезём': 'увезти',
#  'притворитесь': 'притвориться',
#  'тасэо': 'тассо',
#  'приготовим': 'приготовить',
#  'накормлю': 'накормить',
#  'прибудем': 'прибыть',
#  'бошку': 'башку',
#  'располагайся': 'располагаться',
#  'спускайте': 'спускать',
#  'разворачивай': 'разворачивать',
#  'одинешенька': 'одинёшенек',
#  'бухаем': 'бухать',
#  'рискнёшь': 'рискнуть',
#  'порви': 'порвать',
#  'врешь': 'врать',
#  'притащи': 'притащить',
#  'охотимся': 'охотиться',
#  'моюсь': 'мыться',
#  'присядьте': 'присесть',
#  'разыскиваем': 'разыскивать',
#  'истекаешь': 'истекать',
#  'пoнимaю': 'понимаю',
#  'отследят': 'отследить',
#  'оглядись': 'оглядеться',
#  'набирай': 'набирать',
#  'стояком': 'стояк',
#  'поправишься': 'поправиться',
#  'порезались': 'порезаться',
#  'отдолжение': 'одолжение',
#  'промазала': 'промазать',
#  'срывайся': 'срываться',
#  'приземлимся': 'приземлиться',
#  'вяжешь': 'вязать',
#  'спускаешь': 'спускать',
#  'криминалистам': 'криминалист',
#  'уес': 'уис',
#  'инвестирую': 'инвестировать',
#  'огнестрелом': 'огнестрельном',
#  'воспитываешь': 'воспитывать',
#  'хот€': 'хотя',
#  'переезжаешь': 'переезжать',
#  'кружимся': 'кружиться',
#  'выпускай': 'выпускать',
#  'трахаю': 'трахать',
#  'бомине': 'обмене',
#  'вмешивай': 'вмешивать',
#  'сдаетесь': 'сдаваться',
#  'опаздывайте': 'опаздывать',
#  'кредитке': 'кредитка',
#  'перебьем': 'перебить',
#  'концентрируешься': 'концентрироваться',
#  'дерьмовых': 'дерьмовый',
#  'заигрываешь': 'заигрывать',
#  'выгоню': 'выгнать',
#  'падаете': 'падать',
#  'тянись': 'тянуться',
#  'прогоняй': 'прогонять',
#  'обыщите': 'обыскать',
#  'гocпoди': 'господи',
#  'целилась': 'целиться',
#  'прокачусь': 'прокатиться',
#  'веканои': 'вакансии',
#  'ударишь': 'ударить',
#  'mеня': 'меня',
#  'члeн': 'член',
#  'пострадаешь': 'пострадать',
#  'реддингтоном': 'реддингтон',
#  'припаркую': 'припарковать',
#  'стесняйся': 'стесняться',
#  'дуюсь': 'дуться',
#  'напрягитесь': 'напрячься',
#  'голодаем': 'голодать',
#  'моргнули': 'моргнуть',
#  'повеселимся': 'повеселиться',
#  'cкaзaл': 'сказал',
#  'льсти': 'льстить',
#  'колешься': 'колоться',
#  'посадишь': 'посадить',
#  'причиним': 'причинить',
#  'кажемся': 'казаться',
#  'ладите': 'ладить',
#  'избавляешься': 'избавляться',
#  'упускаешь': 'упускать',
#  'скучаешь': 'скучать',
#  'поговрить': 'поговорить',
#  'выпьете': 'выпить',
#  'позаботишься': 'позаботиться',
#  'распознаю': 'распознавать',
#  'обыщу': 'обыскать',
#  'ломаешь': 'ломать',
#  'выбьем': 'выбить',
#  'сопроводит': 'сопроводить',
#  'гребаных': 'гребных',
#  'отрастут': 'отрасти',
#  'наберешь': 'набрать',
#  'опаздываешь': 'опаздывать',
#  'перекусим': 'перекусить',
#  'удивляешь': 'удивлять',
#  'отпразднуем': 'отпраздновать',
#  'mэлоун': 'милан',
#  'запру': 'запереть',
#  'извинишься': 'извиниться',
#  'приглашаешь': 'приглашать',
#  'поужинаешь': 'поужинать',
#  'долбанном': 'долбать',
#  'moй': 'мой',
#  'мауч': 'маус',
#  'приберите': 'прибрать',
#  'видитесь': 'видеться',
#  'срываешь': 'срывать',
#  'убежим': 'убежать',
#  'расстраиваешь': 'расстраивать',
#  'стриптизеры': 'стриптизер',
#  'прилетишь': 'прилететь',
#  'шепчешь': 'шептать',
#  'долбанного': 'долбать',
#  'чepт': 'черт',
#  'завяжешь': 'завязать',
#  'ранишь': 'ранить',
#  'согрею': 'согреть',
#  'слабаки': 'слабак',
#  'держишься': 'держаться',
#  'уложишь': 'уложить',
#  'затеваешь': 'затевать',
#  'добудем': 'добыть',
#  'съезжай': 'съезжать',
#  'подпускайте': 'подпускать',
#  'клянёшься': 'клясться',
#  'разрежем': 'разрезать',
#  'мчись': 'мчаться',
#  'заткнусь': 'заткнуться',
#  'потороплюсь': 'поторопиться',
#  'ржёшь': 'ржать',
#  'heт': 'hey',
#  'задержишь': 'задержать',
#  'впустите': 'впустить',
#  'метишь': 'метить',
#  'кoнeчнo': 'конечно',
#  'думешь': 'думаешь',
#  'располагайтесь': 'располагаться',
#  'взломаю': 'взломать',
#  'грубишь': 'грубить',
#  'освободишься': 'освободиться',
#  'задерживаюсь': 'задерживаться',
#  'попьем': 'попить',
#  'бpaт': 'брат',
#  'томстэй': 'томский',
#  'дл€': 'для',
#  'джуэль': 'дуэль',
#  'засажу': 'засадить',
#  'выслушаете': 'выслушать',
#  'помою': 'помыть',
#  'уступишь': 'уступить',
#  'реддингтона': 'эддингтон',
#  'присмотри': 'присмотреть',
#  'воткни': 'воткнуть',
#  'учуяли': 'учуять',
#  'медэксперта': 'медэксперт',
#  'поболтал': 'поболтать',
#  'перебиваю': 'перебивать',
#  'кметко': 'метко',
#  'гловс': 'глава',
#  'тронете': 'тронуть',
#  'навестим': 'навестить',
#  'драматизируешь': 'драматизировать',
#  'винишь': 'винить',
#  'вылезем': 'вылезти',
#  'рестона': 'ресторан',
#  'взрывай': 'взрывать',
#  'тэррес': 'торрес',
#  'пайрона': 'парана',
#  'пообедаешь': 'пообедать',
#  'развяжите': 'развязать',
#  'болтаешь': 'болтать',
#  'oх': 'os',
#  'сбежим': 'сбежать',
#  'улажу': 'уладить',
#  'писаю': 'писать',
#  'предчуствие': 'предчувствие',
#  'легавого': 'легавый',
#  'придаешь': 'придавать',
#  'производишь': 'производить',
#  'лгуньи': 'лгунья',
#  'истеку': 'истечь',
#  'отрываемся': 'отрываться',
#  'делаты': 'делать',
#  'выкинь': 'выкинуть',
#  'перегнула': 'перегнуть',
#  'арендуем': 'арендовать',
#  'убираюсь': 'убираться',
#  'джемм': 'джем',
#  'беспокоим': 'беспокоить',
#  'перезвоните': 'перезвонить',
#  'поссоримся': 'поссориться',
#  'переспишь': 'переспать',
#  'сердимся': 'сердиться',
#  'задерживаете': 'задерживать',
#  'отдохнете': 'отдохнуть',
#  'кредитками': 'кредитка',
#  'безмозглая': 'безмозглый',
#  'связывайся': 'связываться',
#  'дидем': 'дидим',
#  'столкнешься': 'столкнуться',
#  'приемчик': 'приёмчик',
#  'свисти': 'свистеть',
#  'подслушивала': 'подслушивать',
#  'выезжаем': 'выезжать',
#  'годишься': 'годиться',
#  'завалите': 'завалить',
#  'клоуд': 'клод',
#  'заболеешь': 'заболеть',
#  'шлялся': 'шляться',
#  'тормозишь': 'тормозить',
#  'распланировала': 'распланировать',
#  'надеру': 'надрать',
#  'взлетаем': 'взлетать',
#  'пройдёмте': 'пройти',
#  'стукну': 'стукнуть',
#  'пoгoди': 'погоди',
#  'занеси': 'занести',
#  'хадасс': 'хадис',
#  'проберемся': 'пробраться',
#  'выдумывай': 'выдумывать',
#  'бинджи': 'бенджи',
#  'повернитесь': 'повернуться',
#  'расческой': 'расчёска',
#  'рассаживайтесь': 'рассаживаться',
#  'охренительно': 'охранительный',
#  'улетим': 'улететь',
#  'отступись': 'отступиться',
#  'обьятия': 'объятия',
#  'твoю': 'твою',
#  'заджак': 'зодиак',
#  'нервничаешь': 'нервничать',
#  'лжем': 'лгать',
#  'собьешь': 'сбить',
#  'связываемся': 'связываться',
#  'слезьте': 'слезть',
#  'побеспокоила': 'побеспокоить',
#  'переусердствуй': 'переусердствовать',
#  'благодаришь': 'благодарить',
#  'готовишься': 'готовиться',
#  'мерде': 'морде',
#  'бэйджор': 'пейджер',
#  'флиртуй': 'флиртовать',
#  'разношу': 'разносить',
#  'банчи': 'бани',
#  'воняю': 'вонять',
#  'дядушка': 'дедушка',
#  'обалденно': 'обалденный',
#  'oтлично': 'отлично',
#  'заговоришь': 'заговорить',
#  'трясешься': 'трястись',
#  'вeличecтвo': 'величество',
#  'отодвинься': 'отодвинуться',
#  'сваливаю': 'сваливать',
#  'штучке': 'штучка',
#  'покормлю': 'покормить',
#  'дергаешь': 'дёргать',
#  'удвойте': 'удвоить',
#  'проснешься': 'проснуться',
#  'захлопнись': 'захлопнуться',
#  'обнимешь': 'обнять',
#  'долбаное': 'долбать',
#  'надавите': 'надавить',
#  'отрицай': 'отрицать',
#  'веселюсь': 'веселиться',
#  'исчезаешь': 'исчезать',
#  'поцелуемся': 'поцеловаться',
#  'предохранялись': 'предохраняться',
#  'ювень': 'вен',
#  'замолчишь': 'замолчать',
#  'раздаем': 'раздавать',
#  'разыгрываешь': 'разыгрывать',
#  'сечёшь': 'сечь',
#  'кусаюсь': 'кусаться',
#  'глазел': 'глазеть',
#  'приберу': 'прибрать',
#  'отведем': 'отвести',
#  'педиком': 'педик',
#  'тревожусь': 'тревожиться',
#  'заправимся': 'заправиться',
#  'развернитесь': 'развернуться',
#  'отвернусь': 'отвернуться',
#  'складываешь': 'складывать',
#  'объ€снить': 'объяснить',
#  'ƒжеймс': 'джеймс',
#  'вздернут': 'вздёрнутый',
#  'сбегаем': 'сбегать',
#  'вылезайте': 'вылезать',
#  'расступись': 'расступиться',
#  'займешься': 'заняться',
#  'махну': 'махнуть',
#  'летаете': 'летать',
#  'накрой': 'накрыть',
#  'вобью': 'вбить',
#  'выбирайтесь': 'выбираться',
#  'заберешь': 'забрать',
#  'упустишь': 'упустить',
#  'ƒжон': 'джон',
#  'сожжёшь': 'сжечь',
#  'заткну': 'заткнуть',
#  'унаследую': 'унаследовать',
#  'спускаешься': 'спускаться',
#  'арестовываю': 'арестовывать',
#  'впускай': 'впускать',
#  'пульпо': 'пульпа',
#  'умолкни': 'умолкнуть',
#  'задержись': 'задержаться',
#  'сдаешься': 'сдаваться',
#  'дражайшая': 'дражайший',
#  'приготовлюсь': 'приготовиться',
#  'плывите': 'плыть',
#  'прикройся': 'прикрыться',
#  'стройся': 'строиться',
#  'придуривайся': 'придуриваться',
#  'мурэ': 'мура',
#  'расслабятся': 'расслабиться',
#  'cпacибo': 'спасибо',
#  'разбогатеем': 'разбогатеть',
#  'хилик': 'килик',
#  'прикончу': 'прикончить',
#  '<CENSORED>': 'censored',
#  'перевезём': 'перевезти',
#  'клянешься': 'клясться',
#  'торгуешь': 'торговать',
#  'орошо': 'хорошо',
#  'напрашиваешься': 'напрашиваться',
#  'допросит': 'допросить',
#  'высплюсь': 'выспаться',
#  'одолжим': 'одолжить',
#  'раздобудь': 'раздобыть',
#  'одевай': 'одевать',
#  'гладишь': 'гладить',
#  'задашь': 'задать',
#  'перемотай': 'перемотать',
#  'допросите': 'допросить',
#  'прервите': 'прервать',
#  'привееет': 'привет',
#  'сжульничала': 'сжульничать',
#  'ахх': 'ах',
#  'уложи': 'уложить',
#  'окружите': 'окружить',
#  'утруждай': 'утруждать',
#  'разведемся': 'развестись',
#  'дзюно': 'дзюдо',
#  'выспись': 'выспаться',
#  'покончи': 'покончить',
#  'cюдa': 'суда',
#  'продадите': 'продать',
#  'вдохновляешь': 'вдохновлять',
#  'помиритесь': 'помириться',
#  'влипла': 'влипнуть',
#  'жульничаю': 'жульничать',
#  'себ€': 'себя',
#  'рэглан': 'реглан',
#  'пахнешь': 'пахнуть',
#  'везунчиком': 'везунчик',
#  'понюхайте': 'понюхать',
#  'обвиняй': 'обвинять',
#  'торчишь': 'торчать',
#  'ворчи': 'ворчать',
#  'пялились': 'пялиться',
#  'встречайся': 'встречаться',
#  'мамита': 'мамит',
#  'распоряжаюсь': 'распоряжаться',
#  'заряжаю': 'заряжать',
#  'уведу': 'увести',
#  'выражаешься': 'выражаться',
#  'сорву': 'сорвать',
#  'райзе': 'разе',
#  'побью': 'побить',
#  'значишь': 'значить',
#  'выплатим': 'выплатить',
#  'взбодрит': 'взбодрить',
#  'цыпочку': 'цыпочка',
#  'отступай': 'отступать',
#  'убеждаешь': 'убеждать',
#  'скуб': 'скуба',
#  'выгоняете': 'выгонять',
#  'выключаешь': 'выключать',
#  'мазел': 'масел',
#  'подцепим': 'подцепить',
#  'темми': 'теми',
#  'эйнджэл': 'энджела',
#  'солоний': 'солений',
#  'проживёте': 'прожить',
#  'ворвемся': 'ворваться',
#  'дaй': 'дай',
#  'сдерживайся': 'сдерживаться',
#  'прихватим': 'прихватить',
#  'значу': 'значить',
#  'видимся': 'видеться',
#  'увольняй': 'увольнять',
#  'выкуплю': 'выкупить',
#  'завожусь': 'заводиться',
#  'поживей': 'живой',
#  'катаешься': 'кататься',
#  'злились': 'злиться',
#  'pacтяпa': 'растяпа',
#  'теб€': 'тебя',
#  'храпел': 'храпеть',
#  'переодевайся': 'переодеваться',
#  'распускай': 'распускать',
#  'моргнула': 'моргнуть',
#  'попадайся': 'попадаться',
#  'собьем': 'сбить',
#  'обыщут': 'обыскать',
#  'замочу': 'замочить',
#  'дерьмовые': 'дерьмовый',
#  'откроемся': 'открыться',
#  'умойся': 'умыться',
#  'прикончи': 'прикончить',
#  'обожаешь': 'обожать',
#  'мёртах': 'метрах',
#  'лесситер': 'лестер',
#  'слушайся': 'слушаться',
#  'выкурила': 'выкурить',
#  'пугаешь': 'пугать',
#  'пожмем': 'пожать',
#  'дыхни': 'дыхнуть',
#  'помедленней': 'медленный',
#  'справляешься': 'справляться',
#  'мэнос': 'минос',
#  'потяни': 'потянуть',
#  'поцелуйтесь': 'поцеловаться',
#  'выброси': 'выбросить',
#  'фокусируюсь': 'фокусироваться',
#  'наносишь': 'наносить',
#  'вламываюсь': 'вламываться',
#  'поклянитесь': 'поклясться',
#  'ворус': 'вирус',
#  'вытаскиваем': 'вытаскивать',
#  'джордино': 'джордано',
#  'упадешь': 'упасть',
#  'шевелись': 'шевелиться',
#  'распутия': 'распутья',
#  'осматриваете': 'осматривать',
#  'очнешься': 'очнуться',
#  'соединяешь': 'соединять',
#  'поужинай': 'поужинать',
#  'изобэл': 'изобрел',
#  'выбью': 'выбить',
#  'отпускайте': 'отпускать',
#  'заводишь': 'заводить',
#  'переедешь': 'переехать',
#  'йди': 'иди',
#  'пялюсь': 'пялиться',
#  'крикетт': 'крикет',
#  'икинг': 'кинг',
#  'волнуйс€': 'волнуйся',
#  'темпс': 'темп',
#  'влюблюсь': 'влюбиться',
#  'прижмитесь': 'прижаться',
#  'изображу': 'изобразить',
#  'крэйтер': 'рейтер',
#  'отъезжай': 'отъезжать',
#  'станцую': 'станцевать',
#  'торчите': 'торчать',
#  'устроюсь': 'устроиться',
#  'подбросишь': 'подбросить',
#  'заберусь': 'забраться',
#  'вскроешь': 'вскрыть',
#  'вызывай': 'вызывать',
#  'аббаддон': 'абаддон',
#  'царствое': 'царство',
#  'отвезём': 'отвезти',
#  'прикалываешься': 'прикалываться',
#  'бо€': 'боя',
#  'elderman': 'alderman',
#  'спущу': 'спустить',
#  'практикуюсь': 'практиковаться',
#  'повеселишься': 'повеселиться',
#  'навестите': 'навестить',
#  'писай': 'писать',
#  'мастурбирую': 'мастурбировать',
#  'врем€': 'время',
#  'покончишь': 'покончить',
#  'сплетницу': 'сплетница',
#  'напугай': 'напугать',
#  'завалишь': 'завалить',
#  'подтяни': 'подтянуть',
#  'избавляетесь': 'избавляться',
#  'свали': 'свалить',
#  'амтор': 'автор',
#  'эвакуируем': 'эвакуировать',
#  'разобьешься': 'разбиться',
#  'мешайся': 'мешаться',
#  'надаю': 'надавать',
#  'расслаблюсь': 'расслабиться',
#  'дедуль': 'дедуля',
#  'уговорю': 'уговорить',
#  'повидайся': 'повидаться',
#  'грёбаное': 'гребное',
#  'заметано': 'заметать',
#  'подсади': 'подсадить',
#  'caмoлeт': 'самолет',
#  'мoй': 'мой',
#  'проникнем': 'проникнуть',
#  'грёбаным': 'гребным',
#  'сбежишь': 'сбежать',
#  'озгуд': 'осгуд',
#  'сожми': 'сжать',
#  'аннанцио': 'аннунцио',
#  'доберешься': 'добраться',
#  'отвлекаем': 'отвлекать',
#  'порвите': 'порвать',
#  'здарова': 'здорова',
#  'оплатим': 'оплатить',
#  'ухватится': 'ухватиться',
#  'понравлюсь': 'понравиться',
#  'повзрослеешь': 'повзрослеть',
#  'бичум': 'бичом',
#  'tренер': 'тренер',
#  'пролетим': 'пролететь',
#  'приглашай': 'приглашать',
#  'передохнем': 'передохнуть',
#  'обедаешь': 'обедать',
#  'отпустишь': 'отпустить',
#  'доешь': 'доесть',
#  'вышвырну': 'вышвырнуть',
#  'развлекись': 'развлечься',
#  'залазь': 'залазить',
#  'осмелишься': 'осмелиться',
#  'поспим': 'поспать',
#  'поудобней': 'удобный',
#  'раздражаю': 'раздражать',
#  'гребанной': 'гребенной',
#  'разочаровываешь': 'разочаровывать',
#  'заезжай': 'заезжать',
#  'перезвонят': 'перезвонить',
#  'прирежу': 'прирезать',
#  'прервёмся': 'прерваться',
#  'лажал': 'лежал',
#  'прикуси': 'прикусить',
#  'рэйлан': 'райан',
#  'одолжу': 'одолжить',
#  'исследуешь': 'исследовать',
#  'докладывайте': 'докладывать',
#  'поблагодари': 'поблагодарить',
#  'гребаной': 'гребной',
#  'арестуем': 'арестовать',
#  'угощайся': 'угощаться',
#  'смеёшься': 'смеяться',
#  'прикидывайся': 'прикидываться',
#  'паришь': 'парить',
#  'зажжешь': 'зажечь',
#  'присоединишься': 'присоединиться',
#  'допрашиваю': 'допрашивать',
#  'дэнно': 'дино',
#  'оденешь': 'одеть',
#  'загоняй': 'загонять',
#  'улавливаешь': 'улавливать',
#  'богохульствуй': 'богохульствовать',
#  'айгу': 'агу',
#  'отпустим': 'отпустить',
#  'заразишься': 'заразиться',
#  'шпионю': 'шпионить',
#  'шагги': 'шаги',
#  'накажешь': 'наказать',
#  'поворачивайся': 'поворачиваться',
#  'запираю': 'запирать',
#  'злишься': 'злиться',
#  'прибегу': 'прибежать',
#  'подменишь': 'подменить',
#  'уладим': 'уладить',
#  'подождешь': 'подождать',
#  'навещу': 'навестить',
#  'застрелю': 'застрелить',
#  'бoжe': 'боже',
#  'пристрелишь': 'пристрелить',
#  'пришлём': 'прислать',
#  'появляйся': 'появляться',
#  'контролируй': 'контролировать',
#  'скромничай': 'скромничать',
#  'вдохновляюще': 'вдохновляющие',
#  'перезвонишь': 'перезвонить',
#  'завтракаю': 'завтракать',
#  'доберёшься': 'добраться',
#  'шухере': 'шухер',
#  'кушаешь': 'кушать',
#  'стучалась': 'стучаться',
#  'трастл': 'траст',
#  'бопо': 'опо',
#  'туур': 'тур',
#  'раскисай': 'раскисать',
#  'поместимся': 'поместиться',
#  'согреешься': 'согреться',
#  'понюхай': 'понюхать',
#  'разделимся': 'разделиться',
#  'дотрагивайся': 'дотрагиваться',
#  'отстрелю': 'отстрелить',
#  'ужинаете': 'ужинать',
#  'сюрпризу': 'сюрприз',
#  'отстойное': 'отстойный',
#  'протрезвела': 'протрезветь',
#  'каммо': 'камо',
#  'ёршан': 'аршан',
#  'постройтесь': 'построиться',
#  'разочаруешься': 'разочароваться',
#  'поубивают': 'поубивать',
#  'недооцениваешь': 'недооценивать',
#  'произносишь': 'произносить',
#  'спустим': 'спустить',
#  'разворачивайтесь': 'разворачиваться',
#  'перекусили': 'перекусить',
#  'спущусь': 'спуститься',
#  'увольняешься': 'увольняться',
#  'просканировали': 'просканировать',
#  'волмов': 'волков',
#  'похлопаем': 'похлопать',
#  'слушаешься': 'слушаться',
#  'злишь': 'злить',
#  'повезем': 'повезти',
#  'задерживайся': 'задерживаться',
#  'привозишь': 'привозить',
#  'рейвенсвуде': 'рейвенсвуд',
#  'повеселись': 'повеселиться',
#  'глотайте': 'глотать',
#  'вздрогнем': 'вздрогнуть',
#  'здраствуй': 'здравствуй',
#  'удвой': 'удвоить',
#  'проглотишь': 'проглотить',
#  'повиси': 'повисеть',
#  'стучим': 'стучать',
#  'попей': 'попить',
#  'совру': 'соврать',
#  'загадаешь': 'загадать',
#  'пошалим': 'пошалить',
#  'сбежите': 'сбежать',
#  'порепетируем': 'порепетировать',
#  'зэб': 'зуб',
#  'собираютс€': 'собираются',
#  'малышь': 'малыш',
#  'округлим': 'округлить',
#  'преувеличивай': 'преувеличивать',
#  'раздевайтесь': 'раздеваться',
#  'подыхаю': 'подыхать',
#  'перевяжи': 'перевязать',
#  'сдаёшься': 'сдаваться',
#  'прикидываешься': 'прикидываться',
#  'онечно': 'конечно',
#  'отвлеку': 'отвлечь',
#  'поиграешь': 'поиграть',
#  'оборачивайся': 'оборачиваться',
#  'кланяйтесь': 'кланяться',
#  'упражняюсь': 'упражняться',
#  'допрошу': 'допросить',
#  'приблизь': 'приблизить',
#  'расследуете': 'расследовать',
#  'хатвей': 'матвей',
#  'опаздала': 'опоздала',
#  'уладишь': 'уладить',
#  'ёдди': 'эдди',
#  'имешь': 'имеешь',
#  'устраивайся': 'устраиваться',
#  'срази': 'сразить',
#  'душишь': 'душить',
#  'тусуетесь': 'тусоваться',
#  'разводимся': 'разводиться',
#  'смою': 'смыть',
#  'посоветуешь': 'посоветовать',
#  'mнe': 'мне',
#  'отбираешь': 'отбирать',
#  'мыслишки': 'мыслишка',
#  'пристегнись': 'пристегнуться',
#  'уроню': 'уронить',
#  'расслабимся': 'расслабиться',
#  'пропускай': 'пропускать',
#  'вешаешь': 'вешать',
#  'мюнце': 'мюнцер',
#  'закажем': 'заказать',
#  'превратишь': 'превратить',
#  'кeй': 'гей',
#  'дергайтесь': 'дёргаться',
#  'сожалей': 'сожалеть',
#  'цепляешься': 'цепляться',
#  'оторву': 'оторвать',
#  'трахну': 'трахнуть',
#  'покатаюсь': 'покататься',
#  'присмотришь': 'присмотреть',
#  'потусуюсь': 'потусоваться',
#  'здecь': 'здесь',
#  'проследи': 'проследить',
#  'отследим': 'отследить',
#  'извиняешься': 'извиняться',
#  'отстаете': 'отставать',
#  'подумываешь': 'подумывать',
#  'пpocти': 'прости',
#  'импровизирую': 'импровизировать',
#  'подержишь': 'подержать',
#  'впадаешь': 'впадать',
#  'свернешь': 'свернуть',
#  'врежу': 'вредить',
#  'унижаешь': 'унижать',
#  'застанем': 'застать',
#  'левики': 'велики',
#  'поражаешь': 'поражать',
#  'превращаешь': 'превращать',
#  'поздна': 'поздно',
#  'одобришь': 'одобрить',
#  'раздавлю': 'раздавить',
#  'перевернись': 'перевернуться',
#  'обеспечишь': 'обеспечить',
#  'поплавай': 'поплавать',
#  'тащишься': 'тащиться',
#  'пахну': 'пахнуть',
#  'сердиты': 'сердитый',
#  'замрите': 'замереть',
#  'поведай': 'поведать',
#  'задерживаешь': 'задерживать',
#  'лапал': 'лапать',
#  'трахаешься': 'трахаться',
#  'чeм': 'чем',
#  'задержу': 'задержать',
#  'шевелитесь': 'шевелиться',
#  'долбаная': 'долбать',
#  'шевелите': 'шевелить',
#  'расплатишься': 'расплатиться',
#  'вытаскивай': 'вытаскивать',
#  'отпускаете': 'отпускать',
#  'paбoтaeт': 'работает',
#  'притягиваешь': 'притягивать',
#  'оденьтесь': 'одеться',
#  'флиртуете': 'флиртовать',
#  'высовывался': 'высовываться',
#  'пораню': 'поранить',
#  'трахались': 'трахаться',
#  'налегай': 'налегать',
#  'кобблер': 'коблер',
#  'договорим': 'договорить',
#  'задницам': 'задница',
#  'зарубите': 'зарубить',
#  'остановишься': 'остановиться',
#  'твoй': 'твой',
#  'раздобудешь': 'раздобыть',
#  'переступишь': 'переступить',
#  'засранцем': 'засранец',
#  'припрятала': 'припрятать',
#  'прищучим': 'прищучить',
#  'обменяю': 'обменять',
#  'пoлyчилocь': 'получилось',
#  'подергать': 'подёргать',
#  'побрею': 'побрить',
#  'ейчас': 'сейчас',
#  'выяснишь': 'выяснить',
#  'поженитесь': 'пожениться',
#  'закрываетесь': 'закрываться',
#  'дурачимся': 'дурачиться',
#  'поцелуешь': 'поцеловать',
#  'нагоним': 'нагнать',
#  'отлучусь': 'отлучиться',
#  'cид': 'сид',
#  'алсид': 'оксид',
#  'психованная': 'психованный',
#  'сдвинусь': 'сдвинуться',
#  'даришь': 'дарить',
#  'прострелю': 'прострелить',
#  'хвастаешься': 'хвастаться',
#  'весишь': 'весить',
#  'подождёшь': 'подождать',
#  'повернусь': 'повернуться',
#  'отключайся': 'отключаться',
#  'варишь': 'варить',
#  'ложишься': 'ложиться',
#  'пробуешь': 'пробовать',
#  'джоyи': 'джеки',
#  'поправляешься': 'поправляться',
#  'свидимся': 'свидеться',
#  'домашку': 'домашка',
#  'отвлеките': 'отвлечь',
#  'жрачки': 'зрачки',
#  'закажешь': 'заказать',
#  'постирал': 'постирать',
#  'побудем': 'побыть',
#  'уберешься': 'убраться',
#  'поранься': 'пораниться',
#  'болтаюсь': 'болтаться',
#  'запаникует': 'запаниковать',
#  'сирел': 'сирил',
#  'решишься': 'решиться',
#  'нанеси': 'нанести',
#  'олински': 'долинск',
#  'предаешь': 'предавать',
#  'притворяйся': 'притворяться',
#  'доживешь': 'дожить',
#  'трахаешь': 'трахать',
#  'улыбочку': 'улыбочка',
#  'влюбишься': 'влюбиться',
#  'навещаешь': 'навещать',
#  'обзвонили': 'обзвонить',
#  'идемте': 'идти',
#  'завалимся': 'завалиться',
#  'бесишься': 'беситься',
#  'легавыми': 'легавый',
#  'наладим': 'наладить',
#  'переключу': 'переключить',
#  'взорвём': 'взорвать',
#  'чибс': 'чибис',
#  'развлечёмся': 'развлечься',
#  'чертиков': 'чёртик',
#  'мен€': 'меня',
#  'притворяешься': 'притворяться',
#  'заскочу': 'заскочить',
#  'сломаешься': 'сломаться',
#  'заряжаем': 'заряжать',
#  'погасите': 'погасить',
#  'мсабу': 'саба',
#  'ƒжо': 'джо',
#  'провалишь': 'провалить',
#  'кушаем': 'кушать',
#  'попридержи': 'попридержать',
#  'штако': 'штока',
#  '√оворю': 'говорю',
#  'подкалываю': 'подкалывать',
#  'разыщи': 'разыскать',
#  'оплатишь': 'оплатить',
#  'приказывай': 'приказывать',
#  'помыла': 'помыть',
#  'любовнички': 'любовники',
#  'развлекайся': 'развлекаться',
#  'въезжаешь': 'въезжать',
#  'сдаётесь': 'сдаваться',
#  'поживёшь': 'пожить',
#  'хённим': 'хенина',
#  'спойте': 'спеть',
#  'поздороваюсь': 'поздороваться',
#  'наливаю': 'наливать',
#  'готовишь': 'готовить',
#  'концентрируюсь': 'концентрироваться',
#  'вымоешь': 'вымыть',
#  'приподнимись': 'приподняться',
#  'сдохнешь': 'сдохнуть',
#  'вертишься': 'вертеться',
#  'разогрей': 'разогреть',
#  'кажетесь': 'казаться',
#  'заскучает': 'заскучать',
#  'подыщем': 'подыскать',
#  'наказываю': 'наказывать',
#  'заберёшь': 'забрать',
#  'перепила': 'перепить',
#  'зацикливайся': 'зацикливаться',
#  'позвонишь': 'позвонить',
#  'очистишь': 'очистить',
#  'поведешь': 'повести',
#  'сообщишь': 'сообщить',
#  'напьёмся': 'напиться',
#  'разденусь': 'раздеться',
#  'продержись': 'продержаться',
#  'разрушишь': 'разрушить',
#  'оттащите': 'оттащить',
#  'затыкай': 'затыкать',
#  'гребанная': 'гребенной',
#  'потанцую': 'потанцевать',
#  'прокатишься': 'прокатиться',
#  'повредишь': 'повредить',
#  'прогуляешься': 'прогуляться',
#  'хopoшo': 'хорошо',
#  'мерзавцу': 'мерзавец',
#  'заткнешься': 'заткнуться',
#  'пaпa': 'папа',
#  'залетит': 'залететь',
#  'прячешься': 'прятаться',
#  'блюй': 'блевать',
#  'вьl': 'вью',
#  'утруждайся': 'утруждаться',
#  'чистишь': 'чистить',
#  'отведёшь': 'отвести',
#  'побеспокою': 'побеспокоить',
#  'защитишь': 'защитить',
#  'обходишься': 'обходиться',
#  'орешь': 'орать',
#  'дopoгaя': 'дорогая',
#  'воруешь': 'воровать',
#  'проповедуешь': 'проповедовать',
#  'разваливаюсь': 'разваливаться',
#  'адилин': 'аделин',
#  'грэйсонов': 'грэйсон',
#  'сиднор': 'сидор',
#  'отведешь': 'отвести',
#  'ремонтирую': 'ремонтировать',
#  'осматриваю': 'осматривать',
#  'притворюсь': 'притвориться',
#  'приглядываешь': 'приглядывать',
#  'изобьет': 'избить',
#  'делирио': 'делирия',
#  'баджорское': 'аджарское',
#  'тобеи': 'тобой',
#  'расслышала': 'расслышать',
#  'спускайся': 'спускаться',
#  'опускаешь': 'опускать',
#  'долбанная': 'долбать',
#  'вычти': 'вычесть',
#  'исправишься': 'исправиться',
#  'поторопимся': 'поторопиться',
#  'стэфана': 'стефан',
#  'ухаживаю': 'ухаживать',
#  'сдохну': 'сдохнуть',
#  'клевые': 'клевый',
#  'проедем': 'проехать',
#  'вернутьс€': 'вернуться',
#  'придерживайся': 'придерживаться',
#  'приготовишь': 'приготовить',
#  'шустрее': 'шустрый',
#  'прогуливаю': 'прогуливать',
#  'ённи': 'анни',
#  'закажете': 'заказать',
#  'выслежу': 'выследить',
#  'присмотрим': 'присмотреть',
#  'слезь': 'слезть',
#  'кимбал': 'кимбол',
#  'подвезет': 'подвезти',
#  'гребанного': 'гребенного',
#  'сгорим': 'сгореть',
#  'перезвонит': 'перезвонить',
#  'исчезнете': 'исчезнуть',
#  'вонючем': 'вонючий',
#  'психуешь': 'психовать',
#  'навещаю': 'навещать',
#  'усыновим': 'усыновить',
#  'смущаешь': 'смущать',
#  'ныряю': 'нырять',
#  'спустишься': 'спуститься',
#  'разворачивайте': 'разворачивать',
#  'переставай': 'переставать',
#  'вaшe': 'ваше',
#  'противостою': 'противостоять',
#  'сваливаем': 'сваливать',
#  'удвоим': 'удвоить',
#  'привяжу': 'привязать',
#  'байез': 'без',
#  'закройся': 'закрыться',
#  'вырублю': 'вырубить',
#  'обманете': 'обмануть',
#  'успокоишься': 'успокоиться',
#  'разбудишь': 'разбудить',
#  'глотаю': 'глотать',
#  'заглажу': 'загладить',
#  'боженьки': 'боженька',
#  'манипулируешь': 'манипулировать',
#  'волнуешься': 'волноваться',
#  'джулиетт': 'джульетта',
#  'пoмoгитe': 'помогите',
#  'мухлевал': 'мухлевать',
#  'отвяжите': 'отвязать',
#  'арестуете': 'арестовать',
#  'выдохните': 'выдохнуть',
#  'холодновато': 'холодноватый',
#  'прикрепи': 'прикрепить',
#  'вызови': 'вызвать',
#  'отреагируешь': 'отреагировать',
#  'выключу': 'выключить',
#  'подчиняйся': 'подчиняться',
#  'распространяешь': 'распространять',
#  'подержи': 'подержать',
#  'лорэл': 'орел',
#  'пялится': 'пялиться',
#  'прольем': 'пролить',
#  'разворачивайся': 'разворачиваться',
#  'уволю': 'уволить',
#  'спиттер': 'поттер',
#  'заснешь': 'заснуть',
#  'выбирайся': 'выбираться',
#  'пописала': 'пописать',
#  'лифчиком': 'лифчик',
#  'maмa': 'мама',
#  'пригнитесь': 'пригнуться',
#  'пообедаем': 'пообедать',
#  'оборачивайтесь': 'оборачиваться',
#  'семь€': 'семья',
#  'чeтыpe': 'четыре',
#  'укусишь': 'укусить',
#  'девчачья': 'девчачий',
#  'стыдишься': 'стыдиться',
#  'полоумная': 'полоумный',
#  'дуйся': 'дуться',
#  'обыщи': 'обыскать',
#  'сворачивай': 'сворачивать',
#  'спрячьтесь': 'спрятаться',
#  'надеваешь': 'надевать',
#  'моргни': 'моргнуть',
#  'купаемся': 'купаться',
#  'опоздаешь': 'опоздать',
#  'проникаешь': 'проникать',
#  ...}

# %%
test_unk_to_normal = unk_to_normal_form(test_vocab, vocab_fasttext, config.test_unk)
# Out:
# Loading dictionaries from /Users/kitashov/anaconda/envs/tensorflow/lib/python3.5/site-packages/pymorphy2_dicts/data
# format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168
#   0%|          | 0/351 [00:00<?, ?it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text= HTTP/1.1" 200 2
#   0%|          | 1/351 [00:00<04:18,  1.36it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=* HTTP/1.1" 200 2
#   1%|          | 2/351 [00:01<03:09,  1.84it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B1%D1%83%D1%85%D0%BB%D0%BE%D0%BC HTTP/1.1" 200 97
#   1%|          | 3/351 [00:01<02:47,  2.08it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D0%B4%D0%B5%D1%80%D0%B6%D1%83 HTTP/1.1" 200 2
#   1%|          | 4/351 [00:01<02:34,  2.24it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%88%D0%B5%D0%B2%D0%B5%D0%BB%D0%B8%D1%82%D0%B5%D1%81%D1%8C HTTP/1.1" 200 2
#   1%|▏         | 5/351 [00:02<02:27,  2.35it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B4%D0%B5%D1%80%D1%8C%D0%BC%D0%BE%D0%B2%D1%83%D1%8E HTTP/1.1" 200 2
#   2%|▏         | 6/351 [00:02<02:22,  2.42it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D1%8B%D1%82%D0%B0%D1%81%D0%BA%D0%B8%D0%B2%D0%B0%D0%B9 HTTP/1.1" 200 2
#   2%|▏         | 8/351 [00:02<02:01,  2.83it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D1%81%D0%BA%D0%BE%D1%87%D0%B8%D0%BC HTTP/1.1" 200 2
#   3%|▎         | 9/351 [00:03<02:00,  2.83it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=135 HTTP/1.1" 200 2
#   3%|▎         | 10/351 [00:03<02:00,  2.83it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BE%D0%B1%D1%8B%D1%89%D0%B5%D1%82 HTTP/1.1" 200 2
#   3%|▎         | 11/351 [00:03<02:00,  2.83it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%81%D1%82%D0%BE%D0%BB%D1%8C%D0%BA%D0%BE%D0%B5 HTTP/1.1" 200 2
#   3%|▎         | 12/351 [00:04<01:59,  2.84it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%88%D0%B0%D0%BC%D0%BF%D1%83%D1%81%D0%B8%D0%BA HTTP/1.1" 200 109
#   4%|▎         | 13/351 [00:04<01:59,  2.84it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D0%BA%D1%80%D1%8B%D0%B2%D0%B0%D0%B9%D1%81%D1%8F HTTP/1.1" 200 2
#   4%|▍         | 14/351 [00:04<01:58,  2.84it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%80%D0%B0%D1%81%D0%BF%D0%BE%D0%B7%D0%BD%D0%B0%D1%8E HTTP/1.1" 200 2
#   4%|▍         | 15/351 [00:05<01:58,  2.84it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=38 HTTP/1.1" 200 2
#   5%|▍         | 16/351 [00:05<01:57,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BE%D0%BF%D1%83%D1%85%D0%BB%D0%B0 HTTP/1.1" 200 2
#   5%|▍         | 17/351 [00:05<01:57,  2.84it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D1%80%D0%B8%
  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B3%D0%B5%D1%80%D0%BE%D0%B9%D1%81%D1%82%D0%B2%D1%83%D0%B9 HTTP/1.1" 200 2
#  12%|█▏        | 42/351 [00:14<01:48,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=; HTTP/1.1" 200 2
#  12%|█▏        | 43/351 [00:15<01:47,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%816 HTTP/1.1" 200 78
#  13%|█▎        | 44/351 [00:15<01:47,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%B7%D0%B1%D0%BE%D0%B4%D1%80%D0%B8%D1%81%D1%8C HTTP/1.1" 200 2
#  13%|█▎        | 45/351 [00:15<01:47,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D1%83%D0%BF%D0%B0%D0%BD%D0%B8%D0%BA HTTP/1.1" 200 300
#  13%|█▎        | 46/351 [00:16<01:46,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%C6%92%D0%B6%D0%B5%D0%BA HTTP/1.1" 200 111
#  13%|█▎        | 47/351 [00:16<01:46,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%80%D0%B0%D0%B7%D0%B2%D0%BE%D0%B4%D0%B8%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  14%|█▎        | 48/351 [00:16<01:46,  2.85it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B8%D0%B4%D0%B5%D0%BC%D1%82%D0%B5 HTTP/1.1" 200 2
#  14%|█▍        | 49/351 [00:17<01:45,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D0%B2%D0%B5%D1%81%D0%B5%D0%BB%D0%B8%D0%BC%D1%81%D1%8F HTTP/1.1" 200 2
#  14%|█▍        | 50/351 [00:17<01:45,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=$200 HTTP/1.1" 200 2
#  15%|█▍        | 51/351 [00:17<01:45,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=90 HTTP/1.1" 200 2
#  15%|█▍        | 52/351 [00:18<01:44,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D0%B4%D0%B5%D1%80%D0%B6%D0%B0%D1%82%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  15%|█▌        | 53/351 [00:18<01:44,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=79 HTTP/1.1" 200 2
#  15%|█▌        | 54/351 [00:18<01:43,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%81%D0%BA%D1%83%D1%87%D0%B0%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
#  16%|█▌        | 55/351 [00:19<01:43,  2.86it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D1%81%D0%BB%D1%83%D0%B6%D0%B8 HTTP/1.1" 200 2
#  16%|█▌        | 57/351 [00:19<01:41,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D1%8B%D1%82%D0%B2%D0%BE%D1%80%D1%8F%D0%B5%D1%82%D0%B5 HTTP/1.1" 200 2
#  17%|█▋        | 58/351 [00:19<01:40,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%81%D0%BB%D0%BE%D0%BC%D0%B0%D0%B5%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  17%|█▋        | 59/351 [00:20<01:40,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=15 HTTP/1.1" 200 2
#  17%|█▋        | 60/351 [00:20<01:40,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=100 HTTP/1.1" 200 2
#  17%|█▋        | 61/351 [00:20<01:39,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%95%D0%B0%D0%BF%D0%B0 HTTP/1.1" 200 85
#  18%|█▊        | 62/351 [00:21<01:39,  2.90it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%80%D0%B0%D0%B7%D0%B2%D0%BB%D0%B5%D0%BA%D0%B0%D0%B9%D1%81%D1%8F HTTP/1.1" 200 2
#  18%|█▊        | 63/351 [00:21<01:39,  2.90it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=28 HTTP/1.1" 200 2
#  18%|█▊        | 64/351 [00:22<01:39,  2.90it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=40 HTTP/1.1" 200 2
#  19%|█▊        | 65/351 [00:22<01:38,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B3%D0%BE%D1%82%D0%BE%D0%B2%D0%B8%D1%88%D1%8C HTTP/1.1" 200 2
#  19%|█▉        | 66/351 [00:22<01:38,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=97 HTTP/1.1" 200 2
#  19%|█▉        | 67/351 [00:23<01:38,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B1%D1%8Ci%D0%BB HTTP/1.1" 200 80
#  19%|█▉        | 68/351 [00:23<01:37,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=320 HTTP/1.1" 200 2
#  20%|█▉        | 69/351 [00:23<01:37,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=32 HTTP/1.1" 200 2
#  20%|█▉        | 70/351 [00:24<01:37,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=000 HTTP/1.1" 200 2
#  20%|██        | 71/351 [00:24<01:36,  2.89it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text
  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D1%80%D0%B5%D0%B6%D1%8C HTTP/1.1" 200 2
#  56%|█████▋    | 198/351 [01:07<00:52,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=50 HTTP/1.1" 200 2
#  57%|█████▋    | 199/351 [01:08<00:52,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D1%80%D0%B8%D0%B3%D0%BE%D1%82%D0%BE%D0%B2%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  57%|█████▋    | 200/351 [01:08<00:51,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=125 HTTP/1.1" 200 2
#  57%|█████▋    | 201/351 [01:09<00:51,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B3%D0%BB%D0%BE%D1%82%D0%BD%D1%83 HTTP/1.1" 200 2
#  58%|█████▊    | 202/351 [01:09<00:51,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=35 HTTP/1.1" 200 2
#  58%|█████▊    | 203/351 [01:09<00:50,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%83%D0%B6%D0%B8%D0%BD%D0%B0%D1%8E HTTP/1.1" 200 2
#  58%|█████▊    | 204/351 [01:10<00:50,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%83%D0%BB%D1%8B%D0%B1%D0%BD%D0%B5%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  59%|█████▉    | 207/351 [01:10<00:48,  2.94it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BA9 HTTP/1.1" 200 78
#  59%|█████▉    | 208/351 [01:10<00:48,  2.94it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=84 HTTP/1.1" 200 2
#  60%|█████▉    | 209/351 [01:11<00:48,  2.94it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=16 HTTP/1.1" 200 2
#  60%|█████▉    | 210/351 [01:11<00:47,  2.94it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B4%D0%BE%D1%82%D1%80%D0%B0%D0%B3%D0%B8%D0%B2%D0%B0%D0%B5%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  60%|██████    | 211/351 [01:11<00:47,  2.94it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=409 HTTP/1.1" 200 2
# ...
#  80%|████████  | 282/351 [01:36<00:23,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D1%8B%D0%B3%D0%BE%D0%BD%D0%B8%D1%82%D0%B5 HTTP/1.1" 200 2
#  81%|████████  | 283/351 [01:36<00:23,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B4%D0%B0%D0%B2%D0%B8%D1%88%D1%8C HTTP/1.1" 200 2
#  81%|████████  | 284/351 [01:37<00:22,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BA%D1%80%D0%B5%D0%BD%D0%B4%D0%B5%D0%BB%D1%8C%D0%BA%D0%BE%D0%B2 HTTP/1.1" 200 2
#  81%|████████  | 285/351 [01:37<00:22,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=12 HTTP/1.1" 200 2
#  81%|████████▏ | 286/351 [01:38<00:22,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%BE%D0%B7%D0%B2%D1%80%D0%B0%D1%89%D0%B0%D0%B9 HTTP/1.1" 200 2
#  82%|████████▏ | 287/351 [01:38<00:21,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D1%8B%D1%81%D1%82%D1%80%D0%B5%D0%BB%D1%8E HTTP/1.1" 200 2
#  82%|████████▏ | 288/351 [01:38<00:21,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D1%89%D1%83%D0%BF%D0%B0%D0%B9 HTTP/1.1" 200 2
#  82%|████████▏ | 289/351 [01:39<00:21,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BD%D1%83%D0%B4%D0%B0 HTTP/1.1" 200 2
#  83%|████████▎ | 290/351 [01:39<00:20,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D1%80%D0%B8%D1%87%D0%B8%D0%BD%D1%8F%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
#  83%|████████▎ | 291/351 [01:39<00:20,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=c%D1%8D%D0%BD%D0%B4%D0%B8 HTTP/1.1" 200 118
#  83%|████████▎ | 292/351 [01:40<00:20,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B1%D1%8B%D1%81%D1%82%D1%80%D0%B5%D0%BD%D1%8C%D0%BA%D0%BE%D0%BC%D1%83 HTTP/1.1" 200 2
#  83%|████████▎ | 293/351 [01:40<00:19,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%81%D0%BF%D1%83%D1%89%D1%83%D1%81%D1%8C HTTP/1.1" 200 2
#  84%|████████▍ | 294/351 [01:40<00:19,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%
  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=65 HTTP/1.1" 200 2
#  91%|█████████▏| 321/351 [01:50<00:10,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BE%D1%86%D0%B5%D0%BF%D0%B8%D1%82%D0%B5 HTTP/1.1" 200 2
#  92%|█████████▏| 322/351 [01:50<00:09,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D0%BB%D0%B5%D0%B7%D0%B0%D0%B9 HTTP/1.1" 200 2
#  92%|█████████▏| 323/351 [01:50<00:09,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%BE%D0%B7%D0%B1%D1%83%D0%B4%D0%B8%D0%BB%D0%B0%D1%81%D1%8C HTTP/1.1" 200 2
#  92%|█████████▏| 324/351 [01:51<00:09,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%B5%D1%80%D0%B5%D0%B7%D0%B2%D0%BE%D0%BD%D1%8E HTTP/1.1" 200 2
#  93%|█████████▎| 325/351 [01:51<00:08,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BB%D0%BE%D0%BA%D0%B2%D1%83%D0%B4%D0%BE%D0%B2 HTTP/1.1" 200 109
#  93%|█████████▎| 326/351 [01:51<00:08,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=116 HTTP/1.1" 200 2
#  93%|█████████▎| 327/351 [01:52<00:08,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%88%D0%BC%D0%B0%D0%BB%D0%B8 HTTP/1.1" 200 123
#  93%|█████████▎| 328/351 [01:52<00:07,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D0%BA%D0%B0%D0%B6%D0%B5%D0%BC%D1%81%D1%8F HTTP/1.1" 200 2
#  94%|█████████▎| 329/351 [01:53<00:07,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%B0%D0%BA%D1%83%D0%B9%D1%82%D0%B5 HTTP/1.1" 200 2
#  94%|█████████▍| 330/351 [01:53<00:07,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=200 HTTP/1.1" 200 2
#  94%|█████████▍| 331/351 [01:53<00:06,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%80%D0%B0%D0%B7%D1%83%D0%B7%D0%BD%D0%B0%D1%8E HTTP/1.1" 200 2
#  95%|█████████▍| 332/351 [01:54<00:06,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%86%D0%B5%D0%BB%D1%83%D0%B5%D0%BC%D1%81%D1%8F HTTP/1.1" 200 2
#  95%|█████████▍| 333/351 [01:54<00:06,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D1%8B%D1%81%D1%82%D1%80%D0%B5%D0%BB%D0%B8%D1%88%D1%8C HTTP/1.1" 200 2
#  95%|█████████▌| 334/351 [01:54<00:05,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BC%D0%B8%D1%81%D0%BA%D0%B5%D0%B2%D0%B8%D0%B4%D0%B6 HTTP/1.1" 200 115
#  95%|█████████▌| 335/351 [01:55<00:05,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BA%D0%B0%D1%80%D0%B4%D0%B0%D1%81%D1%81%D0%B8%D0%B5%D0%B9 HTTP/1.1" 200 122
#  96%|█████████▌| 336/351 [01:55<00:05,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%81%D0%B4%D0%BE%D1%85%D0%BD%D0%B5%D0%BC HTTP/1.1" 200 2
#  96%|█████████▌| 337/351 [01:55<00:04,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=18 HTTP/1.1" 200 2
#  96%|█████████▋| 338/351 [01:56<00:04,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B7%D0%B0%D1%81%D1%82%D1%80%D0%B5%D0%BB%D0%B8 HTTP/1.1" 200 2
#  97%|█████████▋| 339/351 [01:56<00:04,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BC%D0%B8%D1%82%D1%81%D1%83%D0%BA%D0%BE HTTP/1.1" 200 103
#  97%|█████████▋| 340/351 [01:56<00:03,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D1%80%D1%8F%D1%87%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
#  97%|█████████▋| 341/351 [01:57<00:03,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%8F%D0%B7%D0%BD%D0%B0%D1%8E HTTP/1.1" 200 124
#  97%|█████████▋| 342/351 [01:57<00:03,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B2%D0%BC%D0%B5%D1%88%D0%B8%D0%B2%D0%B0%D0%B5%D1%88%D1%8C%D1%81%D1%8F HTTP/1.1" 200 2
#  98%|█████████▊| 343/351 [01:57<00:02,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D0%BE%D0%BA%D0%BE%D0%BD%D1%87%D0%B8%D1%88%D1%8C HTTP/1.1" 200 2
#  98%|█████████▊| 344/351 [01:58<00:02,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%BF%D1%80%D0%B8%D0%B1%D0%B8%D1%80%D0%B0%D0%BB%D1%81%D1%8F HTTP/1.1" 200 2
#  98%|█████████▊| 345/351 [01:58<00:02,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%82%D1%80%D0%B0%D1%85%D0%B0%D0%BB%D0%B0%D1%81%D1%8C HTTP/1.1" 200 2
#  99%|█████████▊| 346/351 [01:59<00:01,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%82%D1%8Ci HTTP/1.1" 200 74
#  99%|█████████▉| 347/351 [01:59<00:01,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D0%B8%D0%B7%D0%B1%D0%B5%D0%B3%D0%B0%D0%B5%D1%88%D1%8C HTTP/1.1" 200 2
#  99%|█████████▉| 349/351 [01:59<00:00,  2.92it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=%D1%81%D1%8B%D0%BD%D1%83%D0%BB%D1%8F HTTP/1.1" 200 2
# 100%|█████████▉| 350/351 [02:00<00:00,  2.91it/s]Starting new HTTP connection (1): speller.yandex.net
# http://speller.yandex.net:80 "GET /services/spellservice.json/checkText?text=00 HTTP/1.1" 200 2
# 100%|██████████| 351/351 [02:00<00:00,  2.91it/s]

# %%
len(test_unk_to_normal)
# Out:
# 219

# %%
test_vocab - vocab_fasttext

# %%
test_unk_to_normal
# Out:
# {'<CENSORED>': 'censored',
#  'cэнди': 'синди',
#  'ƒжек': 'джек',
#  'адалинд': 'адалин',
#  'арестуем': 'арестовать',
#  'беспокоим': 'беспокоить',
#  'бичум': 'бичом',
#  'взлетим': 'взлететь',
#  'взлетишь': 'взлететь',
#  'видитесь': 'видеться',
#  'видишься': 'видеться',
#  'винишь': 'винить',
#  'вламывался': 'вламываться',
#  'влюбляемся': 'влюбляться',
#  'вмешиваешься': 'вмешиваться',
#  'возбудилась': 'возбудиться',
#  'возвращай': 'возвращать',
#  'волнуешься': 'волноваться',
#  'впускай': 'впускать',
#  'врежь': 'врезать',
#  'врешь': 'врать',
#  'выгоните': 'выгнать',
#  'выдвигаемся': 'выдвигаться',
#  'выезжаем': 'выезжать',
#  'выключай': 'выключать',
#  'выключишь': 'выключить',
#  'выключу': 'выключить',
#  'вылезайте': 'вылезать',
#  'выпьете': 'выпить',
#  'выруби': 'вырубить',
#  'выстрелишь': 'выстрелить',
#  'выстрелю': 'выстрелить',
#  'вытаскивай': 'вытаскивать',
#  'вытворяете': 'вытворять',
#  'геройствуй': 'геройствовать',
#  'гловс': 'глава',
#  'глотну': 'глотнуть',
#  'готовишь': 'готовить',
#  'гребаные': 'гребные',
#  'давишь': 'давить',
#  'двинешься': 'двинуться',
#  'дергайся': 'дёргаться',
#  'деревенщину': 'деревенщина',
#  'дерьмовую': 'дерьмовый',
#  'джадзии': 'джадзия',
#  'докладывайте': 'докладывать',
#  'дотрагиваешься': 'дотрагиваться',
#  'дэнно': 'дино',
#  'единственна€': 'единственная',
#  'жертвуешь': 'жертвовать',
#  'жинь': 'жизнь',
#  'жолена': 'ален',
#  'заава': 'забава',
#  'заберёшь': 'забрать',
#  'задерживаем': 'задерживать',
#  'задерживайся': 'задерживаться',
#  'задержим': 'задержать',
#  'задержу': 'задержать',
#  'займешься': 'заняться',
#  'закрывайся': 'закрываться',
#  'залезай': 'залезать',
#  'заложите': 'заложить',
#  'заправь': 'заправить',
#  'заскочим': 'заскочить',
#  'заслужи': 'заслужить',
#  'застрели': 'застрелить',
#  'затягивай': 'затягивать',
#  'злишься': 'злиться',
#  'зупаник': 'запасник',
#  'идемте': 'идти',
#  'идиоткой': 'идиотка',
#  'избегаешь': 'избегать',
#  'извиняешься': 'извиняться',
#  'икинг': 'кинг',
#  'испытывай': 'испытывать',
#  'клянетесь': 'клясться',
#  'копаешься': 'копаться',
#  'крадете': 'красть',
#  'крисон': 'крис',
#  'легавого': 'легавый',
#  'локвудов': 'локвуд',
#  'льстишь': 'льстить',
#  'мамита': 'мамит',
#  'мен€': 'меня',
#  'навестим': 'навестить',
#  'надавим': 'надавить',
#  'нанеси': 'нанести',
#  'направляешься': 'направляться',
#  'нэтали': 'натали',
#  'обыщет': 'обыскать',
#  'одевай': 'одевать',
#  'оденешь': 'одеть',
#  'одобряешь': 'одобрять',
#  'одолжением': 'одолжение',
#  'окосама': 'оксана',
#  'опоздаем': 'опоздать',
#  'освободишься': 'освободиться',
#  'отведем': 'отвести',
#  'откладываешь': 'откладывать',
#  'отойдете': 'отойти',
#  'отремонтирую': 'отремонтировать',
#  'отъе': 'отъем',
#  'охотимся': 'охотиться',
#  'оцепите': 'оцепить',
#  'пакуйте': 'паковать',
#  'папином': 'папин',
#  'паришь': 'парить',
#  'пахну': 'пахнуть',
#  'переезжаешь': 'переезжать',
#  'перезвони': 'перезвонить',
#  'перезвоню': 'перезвонить',
#  'переключи': 'переключить',
#  'перережу': 'перерезать',
#  'перережь': 'перерезать',
#  'пересплю': 'переспать',
#  'поаплодируйте': 'поаплодировать',
#  'побудьте': 'побыть',
#  'повернусь': 'повернуться',
#  'повеселимся': 'повеселиться',
#  'повеселитесь': 'повеселиться',
#  'поворачивайся': 'поворачиваться',
#  'подогрею': 'подогреть',
#  'подозреваетесь': 'подозреваться',
#  'подстрелят': 'подстрелить',
#  'позвонишь': 'позвонить',
#  'позирую': 'позировать',
#  'поиграете': 'поиграть',
#  'покажемся': 'показаться',
#  'поклянитесь': 'поклясться',
#  'покончишь': 'покончить',
#  'покормим': 'покормить',
#  'покормлю': 'покормить',
#  'покрашу': 'покрасить',
#  'покушаем': 'покушать',
#  'поплыву': 'поплыть',
#  'поправишься': 'поправиться',
#  'попьем': 'попить',
#  'порежь': 'порезать',
#  'порыбачим': 'порыбачить',
#  'постираю': 'постирать',
#  'потер€л': 'потерял',
#  'потревожила': 'потревожить',
#  'потуши': 'потушить',
#  'пощупай': 'пощупать',
#  'прибирался': 'прибираться',
#  'приготовься': 'приготовиться',
#  'присоединяешься': 'присоединяться',
#  'притворюсь': 'притвориться',
#  'причиняешь': 'причинять',
#  'проек': 'проект',
#  'пройдемте': 'пройти',
#  'проснёшься': 'проснуться',
#  'прячешь': 'прятать',
#  'прячешься': 'прятаться',
#  'пр€мо': 'прямо',
#  'пытаешь': 'пытать',
#  'пэмми': 'пермь',
#  'пялится': 'пялиться',
#  'работенки': 'работёнка',
#  'разбогатеем': 'разбогатеть',
#  'развлекайся': 'развлекаться',
#  'разводишься': 'разводиться',
#  'развожусь': 'разводиться',
#  'разворачивайся': 'разворачиваться',
#  'раздай': 'раздать',
#  'распознаю': 'распознавать',
#  'рассаживайтесь': 'рассаживаться',
#  'рассредоточьтесь': 'рассредоточиться',
#  'рванет': 'рвануть',
#  'ротстин': 'ростин',
#  'сбиваешь': 'сбивать',
#  'свяжемся': 'связаться',
#  'сдержим': 'сдержать',
#  'сдохнем': 'сдохнуть',
#  'скиттеры': 'скутеры',
#  'скучаешь': 'скучать',
#  'сломаешься': 'сломаться',
#  'согрею': 'согреть',
#  'соединяйте': 'соединять',
#  'сосчитаю': 'сосчитать',
#  'спланируем': 'спланировать',
#  'сплетницу': 'сплетница',
#  'справляешься': 'справляться',
#  'спускайся': 'спускаться',
#  'спускаю': 'спускать',
#  'спущусь': 'спуститься',
#  'сражаешься': 'сражаться',
#  'стяну': 'стянуть',
#  'сфокусируйся': 'сфокусироваться',
#  'схватим': 'схватить',
#  'съедите': 'съесть',
#  'съезжай': 'съезжать',
#  'теб€': 'тебя',
#  'трахалась': 'трахаться',
#  'трахаю': 'трахать',
#  'убегаешь': 'убегать',
#  'уберёмся': 'убраться',
#  'убираюсь': 'убираться',
#  'уволишься': 'уволиться',
#  'угомонись': 'угомониться',
#  'уес': 'уис',
#  'ужинаю': 'ужинать',
#  'улыбнешься': 'улыбнуться',
#  'упадешь': 'упасть',
#  'упустишь': 'упустить',
#  'усложняй': 'усложнять',
#  'уступишь': 'уступить',
#  'фином': 'феном',
#  'хэдди': 'эдди',
#  'целуемся': 'целоваться',
#  'чизбургеров': 'чизбургер',
#  'чудика': 'чудик',
#  'шамото': 'шамота',
#  'шевелись': 'шевелиться',
#  'шевелитесь': 'шевелиться',
#  'шлялся': 'шляться',
#  'шмали': 'шмели',
#  '√рег': 'грег',
#  '√рейсон': 'грейсон'}

# %%
unk_dict = {**train_unk_to_normal, **test_unk_to_normal}

# %%
set(unk_dict.keys())
# Out:
# {'перекуси',
#  '√рег',
#  'zogo',
#  'заберем',
#  'отследи',
#  'джэд',
#  'трахайся',
#  'дуюсь',
#  'привлекаешь',
#  'закрывайся',
#  'тасэо',
#  'накормлю',
#  'бошку',
#  'располагайся',
#  'бухаем',
#  'рискнёшь',
#  'врешь',
#  'работенки',
#  'охотимся',
#  'пoнимaю',
#  'оглядись',
#  'набирай',
#  'стояком',
#  'порезались',
#  'отдолжение',
#  'промазала',
#  'срывайся',
#  'готовишься',
#  'вяжешь',
#  'спускаешь',
#  'криминалистам',
#  'гребаные',
#  'уволю',
#  'инвестирую',
#  'огнестрелом',
#  'угомонись',
#  'кружимся',
#  'выпускай',
#  'ƒжон',
#  'заигрываешь',
#  'вмешивай',
#  'влюбляемся',
#  'сдаетесь',
#  'задашь',
#  'опаздывайте',
#  'кредитке',
#  'жульничаю',
#  'падаете',
#  'обыщите',
#  'ударишь',
#  'члeн',
#  'пострадаешь',
#  'реддингтоном',
#  'зупаник',
#  'разлила',
#  'напрягитесь',
#  'повеселимся',
#  'льсти',
#  'заезжай',
#  'ладите',
#  'избавляешься',
#  'скучаешь',
#  'поговрить',
#  'позаботишься',
#  'гребаных',
#  'отпразднуем',
#  'mэлоун',
#  'пpocти',
#  'извинишься',
#  'приглашаешь',
#  'cид',
#  'мауч',
#  'приберите',
#  'срываешь',
#  'расстраиваешь',
#  'стриптизеры',
#  'прилетишь',
#  'чepт',
#  'завяжешь',
#  'ранишь',
#  'слабаки',
#  'зацикливайся',
#  'присмотришь',
#  'затеваешь',
#  'добудем',
#  'съезжай',
#  'клянёшься',
#  'мчись',
#  'деревенщину',
#  'откладываешь',
#  'думешь',
#  'располагайтесь',
#  'проснёшься',
#  'подогрею',
#  'задерживаюсь',
#  'попьем',
#  'бpaт',
#  'засажу',
#  'выслушаете',
#  'помою',
#  'съездишь',
#  'реддингтона',
#  'одолжением',
#  'учуяли',
#  'медэксперта',
#  'кметко',
#  'окосама',
#  'гловс',
#  'вылезем',
#  'тэррес',
#  'пайрона',
#  'пообедаешь',
#  'oх',
#  'легавого',
#  'производишь',
#  'отрываемся',
#  'делаты',
#  'беспокоим',
#  'перезвоните',
#  'поссоримся',
#  'попей',
#  'сердимся',
#  'связывайся',
#  'свисти',
#  'подслушивала',
#  'годишься',
#  'закажете',
#  'надеру',
#  'пройдёмте',
#  'стукну',
#  'пoгoди',
#  'занеси',
#  'хадасс',
#  'отгула',
#  'расческой',
#  'рассаживайтесь',
#  'обьятия',
#  'бомине',
#  'заджак',
#  'лжем',
#  'слезьте',
#  'бэйджор',
#  'отрастут',
#  'воняю',
#  'oтлично',
#  'согрею',
#  'отодвинься',
#  'покормлю',
#  'проснешься',
#  'врежь',
#  'надавите',
#  'отрицай',
#  'мерде',
#  'исчезаешь',
#  'поцелуемся',
#  'рассредоточьтесь',
#  'ювень',
#  'замолчишь',
#  'раздаем',
#  'разыгрываешь',
#  'сечёшь',
#  'кусаюсь',
#  'встретьте',
#  'разделитесь',
#  'педиком',
#  'заправимся',
#  'сжульничала',
#  'развернитесь',
#  'объ€снить',
#  'жинь',
#  'вздернут',
#  'сфокусируйся',
#  'накрой',
#  'вобью',
#  'выбирайтесь',
#  'упустишь',
#  'арестовываю',
#  'впускай',
#  'задержись',
#  'вдохновляюще',
#  'плывите',
#  'прикройся',
#  'стройся',
#  'мурэ',
#  'жертвуешь',
#  'расслабятся',
#  'присмотрим',
#  'cпacибo',
#  'хилик',
#  'округлим',
#  '<CENSORED>',
#  'перевезём',
#  '√рейсон',
#  'выруби',
#  'орошо',
#  'раздобудь',
#  'пахну',
#  'вдохновляешь',
#  'помиритесь',
#  'рэглан',
#  'пахнешь',
#  'везунчиком',
#  'понюхайте',
#  'обвиняй',
#  'пялились',
#  'выражаешься',
#  'сорву',
#  'выплатим',
#  'взбодрит',
#  'сиднор',
#  'адилин',
#  'выключаешь',
#  'шустрее',
#  'разбудишь',
#  'порежь',
#  'ворвемся',
#  'дaй',
#  'сдерживайся',
#  'прихватим',
#  'увольняй',
#  'выкуплю',
#  'pacтяпa',
#  'теб€',
#  'распускай',
#  'улыбнешься',
#  'попадайся',
#  'собьем',
#  'спалишь',
#  'обожаешь',
#  'двинешься',
#  'осчастливишь',
#  'выкурила',
#  'шамото',
#  'помедленней',
#  'поцелуйтесь',
#  'фокусируюсь',
#  'наносишь',
#  'ворус',
#  'распутия',
#  'очнешься',
#  'поужинай',
#  'клянетесь',
#  'изобэл',
#  'выбью',
#  'приглядывай',
#  'волнуйс€',
#  'влюблюсь',
#  'съеду',
#  'пялился',
#  'подбросишь',
#  'замолкни',
#  'заберусь',
#  'вскроешь',
#  'аббаддон',
#  'царствое',
#  'бо€',
#  'практикуюсь',
#  'тянись',
#  'мастурбирую',
#  'врем€',
#  'сплетницу',
#  'напугай',
#  'выбьем',
#  'подтяни',
#  'проек',
#  'амтор',
#  'разобьешься',
#  'надаю',
#  'расслаблюсь',
#  'уговорю',
#  'пэмми',
#  'заметано',
#  'сбежишь',
#  'выкинь',
#  'озгуд',
#  'доберешься',
#  'чудика',
#  'здарова',
#  'повзрослеешь',
#  'банчи',
#  'tренер',
#  'передохнем',
#  'отпустишь',
#  'доешь',
#  'вышвырну',
#  'развлекись',
#  'осмелишься',
#  'поспим',
#  'поудобней',
#  'перезвонят',
#  'придуривайся',
#  'потуши',
#  'прирежу',
#  'лажал',
#  'уведу',
#  'арестуем',
#  'смеёшься',
#  'паришь',
#  'значу',
#  'загоняй',
#  'богохульствуй',
#  'заразишься',
#  'повидайся',
#  'запираю',
#  'гребанной',
#  'подменишь',
#  'пристрелишь',
#  'пришлём',
#  'скромничай',
#  'перезвонишь',
#  'завтракаю',
#  'доберёшься',
#  'шухере',
#  'стучалась',
#  'допрошу',
#  'поместимся',
#  'разделимся',
#  'дотрагивайся',
#  'сюрпризу',
#  'отстойное',
#  'заряжаем',
#  'отходишь',
#  'ёршан',
#  'постройтесь',
#  'грубишь',
#  'cэнди',
#  'спустим',
#  'спущусь',
#  'просканировали',
#  'волмов',
#  'похлопаем',
#  'рейвенсвуде',
#  'вздрогнем',
#  'здраствуй',
#  'удвой',
#  'стучим',
#  'хopoшo',
#  'совру',
#  'загадаешь',
#  'пошалим',
#  'сбежите',
#  'порепетируем',
#  'зэб',
#  'собираютс€',
#  'малышь',
#  'преувеличивай',
#  'раздевайтесь',
#  'онечно',
#  'отвлеку',
#  'сбегу',
#  'оцепите',
#  'кланяйтесь',
#  'возбудилась',
#  'опаздала',
#  'ёдди',
#  'устраивайся',
#  'локвудов',
#  'душишь',
#  'тусуетесь',
#  'разводимся',
#  'смою',
#  'покажемся',
#  'mнe',
#  'посидишь',
#  'уроню',
#  'пропускай',
#  'залезайте',
#  'превратишь',
#  'tам',
#  'прижми',
#  'уволюсь',
#  'отстаете',
#  'поладите',
#  'писаю',
#  'телека',
#  'унижаешь',
#  'застанем',
#  'прооперируют',
#  'раздавлю',
#  'перевернись',
#  'тащишься',
#  'поведай',
#  'задерживаешь',
#  'лапал',
#  'шевелите',
#  'расплатишься',
#  'вытаскивай',
#  'paбoтaeт',
#  'притягиваешь',
#  'обыщет',
#  'оденьтесь',
#  'распознаю',
#  'трахались',
#  'пораню',
#  'налегай',
#  'наберешь',
#  'договорим',
#  'зарубите',
#  'переступишь',
#  'засранцем',
#  'отремонтирую',
#  'прищучим',
#  'подергать',
#  'побрею',
#  'ейчас',
#  'убираюсь',
#  'поженитесь',
#  'закрываетесь',
#  'отлучусь',
#  'алсид',
#  'психованная',
#  'сдвинусь',
#  'хвастаешься',
#  'подождёшь',
#  'повернусь',
#  'отключайся',
#  'ложишься',
#  'свидимся',
#  'домашку',
#  'постирал',
#  'побудем',
#  'геройствуй',
#  'поранься',
#  'запаникует',
#  'решишься',
#  'доживешь',
#  'влюбишься',
#  'навещаешь',
#  'бесишься',
#  'переключу',
#  'взорвём',
#  'развлечёмся',
#  'чертиков',
#  'мен€',
#  'притворяешься',
#  'бопо',
#  'заскочу',
#  'заслужи',
#  'погасите',
#  'ƒжо',
#  'кушаем',
#  'попридержи',
#  'уладишь',
#  '√оворю',
#  'оплатишь',
#  'помыла',
#  'развлекайся',
#  'въезжаешь',
#  'хённим',
#  'высовывался',
#  'спойте',
#  'поздороваюсь',
#  'олински',
#  'наливаю',
#  'готовишь',
#  'концентрируюсь',
#  'подыщем',
#  'оттащите',
#  'наказываю',
#  'заберёшь',
#  'затягивай',
#  'очистишь',
#  'поведешь',
#  'напьёмся',
#  'разденусь',
#  'продержись',
#  'гребанная',
#  'прогуляешься',
#  'aй',
#  'заткнешься',
#  'пaпa',
#  'залетит',
#  'прячешься',
#  'чистишь',
#  'отведёшь',
#  'орешь',
#  'разваливаюсь',
#  'отведешь',
#  'освежусь',
#  'ремонтирую',
#  'приглядываешь',
#  'делирио',
#  'тобеи',
#  'расслышала',
#  'звини',
#  'долбанная',
#  'вычти',
#  'исправишься',
#  'поторопимся',
#  'лижи',
#  'ухаживаю',
#  'съедите',
#  'приготовишь',
#  'прогуливаю',
#  'подстрелят',
#  'слезь',
#  'весишь',
#  'кимбал',
#  'подвезет',
#  'гребанного',
#  'сгорим',
#  'захвачу',
#  'перезвонит',
#  'исчезнете',
#  'навещаю',
#  'потревожила',
#  'ныряю',
#  'разворачивайте',
#  'спускайте',
#  'вaшe',
#  'отбивай',
#  'переставай',
#  'противостою',
#  'долбанное',
#  'удвоим',
#  'привяжу',
#  'переезжаешь',
#  'обманете',
#  'глотаю',
#  'манипулируешь',
#  'джулиетт',
#  'мухлевал',
#  'выдохните',
#  'холодновато',
#  'долбанном',
#  'вызови',
#  'прикрепи',
#  'видитесь',
#  'подчиняйся',
#  'задержим',
#  'лорэл',
#  'пялится',
#  'лгуньи',
#  'спиттер',
#  'заснешь',
#  'джемм',
#  'выбирайся',
#  'пригнитесь',
#  'пообедаем',
#  'оборачивайтесь',
#  'уберёмся',
#  'семь€',
#  'укусишь',
#  'стыдишься',
#  'обнимешь',
#  'обыщи',
#  'спрячьтесь',
#  'надеваешь',
#  'моргни',
#  'купаемся',
#  'опоздаешь',
#  'проникаешь',
#  'поплыву',
#  'поужинаем',
#  'укладываешь',
#  'придушу',
#  'хватаем',
#  'запираем',
#  'задерживаем',
#  'хoчешь',
#  'путешествуешь',
#  'рэйлана',
#  'цыпочку',
#  'свяжемся',
#  'приветики',
#  'дорога€',
#  'дерешься',
#  'понадобитесь',
#  'mистер',
#  'потребуешь',
#  'опоили',
#  'избавляетесь',
#  'пр€мо',
#  'выдвигаемся',
#  'подстрелила',
#  'зурански',
#  'сдержим',
#  'поворачивайся',
#  'переночую',
#  'расплатись',
#  'забираешь',
#  'высади',
#  'взорви',
#  'подготовлюсь',
#  'разрежу',
#  'казню',
#  'подгоняй',
#  'сойдем',
#  'закрепи',
#  'надавим',
#  'поживаю',
#  'чизбургеров',
#  'покажись',
#  'разозлюсь',
#  'сдержишь',
#  'идёмте',
#  'отчитываешься',
#  'чтобь',
#  'спускай',
#  'махало',
#  'бьıть',
#  'tебе',
#  'защитишь',
#  'устанавливай',
#  'исчезните',
#  'постираю',
#  'спрячемся',
#  'отступайте',
#  'трахаемся',
#  'ужинаю',
#  'познакомишься',
#  'подпишешь',
#  'mисс',
#  'переоденусь',
#  'задохнусь',
#  'искуплю',
#  'побежишь',
#  'завяжем',
#  'дотрагиваешься',
#  'сегодн€',
#  'эгоисткой',
#  'соедини',
#  'проведаю',
#  'подпевай',
#  'пригласишь',
#  'заткнёшься',
#  'объявишься',
#  'подойдёшь',
#  'усложняй',
#  'пострадаете',
#  'скрываемся',
#  'приступаешь',
#  'поужинаете',
#  'пройдемте',
#  'проснемся',
#  'свалишь',
#  'расследуете',
#  'чeрт',
#  'разведёмся',
#  'cмoтpитe',
#  'хэдди',
#  'задроты',
#  'рылась',
#  'выиграйте',
#  'кладите',
#  'организовываю',
#  'фином',
#  'расцелую',
#  'просрал',
#  'покормим',
#  'слушаемся',
#  'отрежешь',
#  'закричишь',
#  'выражайся',
#  'присяду',
#  'увиливаешь',
#  'впускаю',
#  'разверни',
#  'порыбачим',
#  'доакса',
#  'привезите',
#  'присоединяешься',
#  'samcro',
#  'клевым',
#  'тoже',
#  'придерживай',
#  'тянешь',
#  'раздай',
#  'прислушиваешься',
#  'отдышись',
#  'подглядывала',
#  'дергаешь',
#  'потерпишь',
#  'потрогаю',
#  'гребаную',
#  'пересекаем',
#  'отведем',
#  'усыновим',
#  'опаздывай',
#  'всажу',
#  'калинде',
#  'пульпо',
#  'опоздаем',
#  'сумашедшая',
#  'влипла',
#  'завтракаем',
#  'отступай',
#  'перемотайте',
#  'клевое',
#  'выпроводи',
#  'опережаю',
#  'обыщут',
#  'разоблачу',
#  'интересуешь',
#  'ƒавай',
#  'перережь',
#  'поиграете',
#  'испытывай',
#  'скорбить',
#  'зажжешь',
#  'ёбтить',
#  'блефуешь',
#  'сидман',
#  'перепроверь',
#  'разбужу',
#  'навещу',
#  'отвезу',
#  'отсосал',
#  'ааах',
#  'заложите',
#  'одинешенек',
#  'просыпайтесь',
#  'ужинаете',
#  'выгоните',
#  'давишь',
#  'злоупотребляешь',
#  'отпустим',
#  'командуй',
#  'вывернет',
#  'приложи',
#  'пощупай',
#  'позавтракаем',
#  'свернешь',
#  'понежнее',
#  'привязываешься',
#  'понюхай',
#  'джоун',
#  'глотни',
#  'наймем',
#  'прокрути',
#  'возглавляешь',
#  'дёргайся',
#  'прибралась',
#  'закончи',
#  'сливай',
#  'свезло',
#  'запри',
#  'прерывайте',
#  'стыдись',
#  'водишь',
#  'поприветствуйте',
#  'надула',
#  'выбираюсь',
#  'дергайся',
#  'незрело',
#  'тшшш',
#  'отберешь',
#  'отвезешь',
#  'тво€',
#  'усугубляй',
#  'залезай',
#  'сдаемся',
#  'роузвуде',
#  'женишься',
#  'метишь',
#  'уладите',
#  'перезвоню',
#  'трахнула',
#  'подбирай',
#  'тусуешься',
#  'позвоним',
#  'промахнешься',
#  'пoйди',
#  'отталкиваешь',
#  'еперь',
#  'сдашься',
#  'переломаю',
#  'отдохнёшь',
#  'напугаете',
#  'прикрывай',
#  'вырубим',
#  'предчуствие',
#  'вырубите',
#  'подвезу',
#  'увольняюсь',
#  'хороша€',
#  'отключи',
#  'прячешь',
#  'повеселилась',
#  'перестарайся',
#  'останавливаешь',
#  'трахалась',
#  'единственна€',
#  'мезаре',
#  'покатаемся',
#  '√осподи',
#  'шэйд',
#  'прикусил',
#  'оплати',
#  'блюй',
#  'ржешь',
#  'фетч',
#  'дерьмового',
#  'заскочим',
#  'ватит',
#  'увезём',
#  'притворитесь',
#  'опаздываешь',
#  'приготовим',
#  'запру',
#  'прибудем',
#  'переждем',
#  'разворачивай',
#  'одинешенька',
#  'порви',
#  'притащи',
#  'поаплодируйте',
#  'отъе',
#  'моюсь',
#  'присядьте',
#  'toгдa',
#  'отследят',
#  'поправишься',
#  'приземлимся',
#  'уес',
#  'спускаю',
#  'воспитываешь',
#  'хот€',
#  'трахаю',
#  'сосчитаю',
#  'шпионю',
#  'перебьем',
#  'концентрируешься',
#  'дерьмовых',
#  'выгоню',
#  'прогоняй',
#  'целилась',
#  'прокачусь',
#  'mеня',
#  'истекаешь',
#  'ƒжек',
#  'припаркую',
#  'стесняйся',
#  'разводишься',
#  'голодаем',
#  'моргнули',
#  'caмoлeт',
#  'cкaзaл',
#  'колешься',
#  'причиним',
#  'кажемся',
#  'упускаешь',
#  'разочаруешься',
#  'столкнешься',
#  'обыщу',
#  'произносишь',
#  'ломаешь',
#  'сопроводит',
#  'перекусим',
#  'удивляешь',
#  'поужинаешь',
#  'moй',
#  'убежим',
#  'шепчешь',
#  'уложишь',
#  'подпускайте',
#  'разрежем',
#  'заткнусь',
#  'потороплюсь',
#  'ржёшь',
#  'задержишь',
#  'впустите',
#  'кoнeчнo',
#  'спланируем',
#  'спустишься',
#  'взлетишь',
#  'адалинд',
#  'повеселитесь',
#  'взломаю',
#  'освободишься',
#  'томстэй',
#  'трева',
#  'джуэль',
#  'уступишь',
#  'присмотри',
#  'воткни',
#  'поболтал',
#  'перебиваю',
#  'повезу',
#  'тронете',
#  'навестим',
#  'винишь',
#  'рестона',
#  'взрывай',
#  'сестренке',
#  'развяжите',
#  'сбежим',
#  'улажу',
#  'пугаешь',
#  'придаешь',
#  'истеку',
#  'перегнула',
#  'арендуем',
#  'переспишь',
#  'задерживаете',
#  'кредитками',
#  'безмозглая',
#  'дидем',
#  'приемчик',
#  'выезжаем',
#  'завалите',
#  'заболеешь',
#  'шлялся',
#  'тормозишь',
#  'распланировала',
#  'взлетаем',
#  'проберемся',
#  'выдумывай',
#  'бинджи',
#  'охренительно',
#  'вpeмя',
#  'улетим',
#  'направляйся',
#  'отступись',
#  'нервничаешь',
#  'собьешь',
#  'связываемся',
#  'побеспокоила',
#  'переусердствуй',
#  'благодаришь',
#  'посадишь',
#  'флиртуй',
#  'дядушка',
#  'обалденно',
#  'заговоришь',
#  'трясешься',
#  'вeличecтвo',
#  'задерживайся',
#  'просрать',
#  'сваливаю',
#  'штучке',
#  'захлопнись',
#  'долбаное',
#  'веселюсь',
#  'разношу',
#  'предохранялись',
#  'удвойте',
#  'глазел',
#  'приберу',
#  'тревожусь',
#  'отвернусь',
#  'складываешь',
#  'ƒжеймс',
#  'взлетим',
#  'мамита',
#  'сбегаем',
#  'вылезайте',
#  'расступись',
#  'махну',
#  'летаете',
#  'заберешь',
#  'сожжёшь',
#  'заткну',
#  'спускаешься',
#  'заава',
#  'идиоткой',
#  'умолкни',
#  'сдаешься',
#  'дражайшая',
#  'приготовлюсь',
#  'злишь',
#  'разбогатеем',
#  'прикончу',
#  'клянешься',
#  'торгуешь',
#  'напрашиваешься',
#  'допросит',
#  'высплюсь',
#  'гocпoди',
#  'одолжим',
#  'закажем',
#  'одевай',
#  'здecь',
#  'перемотай',
#  'допросите',
#  'прервите',
#  'привееет',
#  'ахх',
#  'уложи',
#  'окружите',
#  'утруждай',
#  'разведемся',
#  'дзюно',
#  'крадете',
#  'выспись',
#  'покончи',
#  'cюдa',
#  'продадите',
#  'себ€',
#  'торчишь',
#  'ворчи',
#  'распоряжаюсь',
#  'вертишься',
#  'райзе',
#  'побью',
#  'значишь',
#  'убеждаешь',
#  'скуб',
#  'выгоняете',
#  'мазел',
#  ...}

# %%
np.save(config.unk_dict, unk_dict)

# %%
vocab = (train_vocab | test_vocab  | set(unk_dict.keys())) & vocab_fasttext
vocab.add(UNK)
vocab.add(NUM)
vocab.add(BEGIN)
vocab.add(END)

# %%
len(train_vocab)
# Out:
# 41059

# %%
len(test_vocab)
# Out:
# 10903

# %%
len(vocab_fasttext)
# Out:
# 1862491

# %%
len(vocab)
# Out:
# 40961

# %%
write_vocab(vocab, config.filename_words)
# Out:
# Writing vocab...
# - done. 40961 tokens

# %%
vocab = load_vocab(config.filename_words)

# %%
export_trimmed_glove_vectors(vocab, config.filename_glove,
                                config.filename_trimmed, config.dim_word)

# %%
"я" in vocab_fasttext
# Out:
# True
